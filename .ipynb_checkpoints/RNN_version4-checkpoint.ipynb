# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from time import time
import random

# %%
file_1 = 'Small_Dataset_of_Good_APIs_2.csv'
production_data = pd.read_csv(file_1)

file_2 = './save/All_saved_parameters_20190211194512.csv'
parameters_data = pd.read_csv(file_2)

# %%
min_qi = parameters_data['qi'].quantile(0.05)
max_qi = parameters_data['qi'].quantile(0.95)

min_di = parameters_data['di'].quantile(0.05)
max_di = parameters_data['di'].quantile(0.95)

min_b = parameters_data['b'].quantile(0.05)
max_b = parameters_data['b'].quantile(0.95)

parameters_data['qi_norm'] = (parameters_data['qi']-min_qi)/(max_qi-min_qi)
parameters_data['di_norm'] = (parameters_data['di']-min_di)/(max_di-min_di)
parameters_data['b_norm'] = (parameters_data['b']-min_b)/(max_b-min_b)

# %%
ydata = parameters_data[['qi_norm', 'di_norm', 'b_norm']].as_matrix()

# %%
Xdata = np.zeros(shape=(parameters_data.shape[0], 90, 2))-1

# %%
sample = 0

max_cum_days = 0

for API_NUMBER in parameters_data['API_NUMBER']:
    #print(API_NUMBER, sample)
    selected_production_data = pd.DataFrame()
    selected_production_data = production_data.loc[production_data['API_NUMBER']==API_NUMBER, ['OIL_PROD_DAYS', 'OIL_PRODUCTION_BBL']]
    selected_production_data = selected_production_data.dropna()
    selected_production_data = selected_production_data.loc[selected_production_data['OIL_PRODUCTION_BBL']>0]
    selected_production_data['RATE_PROD'] = selected_production_data['OIL_PRODUCTION_BBL']/selected_production_data['OIL_PROD_DAYS']
    selected_production_data['CUM_DAYS'] = selected_production_data['OIL_PROD_DAYS'].cumsum()
    t = selected_production_data['CUM_DAYS']
    q = selected_production_data['RATE_PROD']
    if (max_cum_days < selected_production_data['CUM_DAYS'].max()):
        max_cum_days = selected_production_data['CUM_DAYS'].max()
    Xdata[sample, 0:t.shape[0], 0] = t
    Xdata[sample, 0:t.shape[0], 1] = q
    sample += 1

# %%
max_month=round(max_cum_days/30)
max_month
# Out:
# 88.0

# %%
def func_hyp(t, qi, di, b):
    return qi/((1+di*b*t)**(1/b))

# %%
number_of_synth_examples = 20000

Xdata_synth = np.zeros(shape=(number_of_synth_examples, 90, 2))-1
ydata_synth = np.zeros(shape=(number_of_synth_examples, 3))

for i in range(number_of_synth_examples):
    #print(i)
    qi_synth = random.uniform(min_qi, max_qi)
    di_synth = random.uniform(min_di, max_di)
    b_synth = random.uniform(min_b, max_b)
    
    qi_synth_norm = (qi_synth-min_qi)/(max_qi-min_qi)
    di_synth_norm = (di_synth-min_di)/(max_di-min_di)
    b_synth_norm = (b_synth-min_b)/(max_b-min_b)
    
    
    ydata_synth[i, :] = [qi_synth_norm, di_synth_norm, b_synth_norm]
    
    cum_months_synth = random.randint(12, max_month)
    start_day_synth = random.randint(5,30)
    
    j=0
    for cum_days_synth in range(start_day_synth, cum_months_synth*30, 30):
        production_noise = random.random()
        production_synth = func_hyp(cum_days_synth, qi_synth, di_synth, b_synth)*(1+production_noise)
        Xdata_synth[i, j, :] = [cum_days_synth, production_synth]
        j += 1

# %%
sample_for_plot = 670

plt.plot(Xdata_synth[sample_for_plot,:,0], Xdata_synth[sample_for_plot,:,1], 'b.')
plt.show()

# %%
import keras
from keras.models import Sequential  
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.layers import InputLayer
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
# Out:
# Using TensorFlow backend.

# %%
input_shape = (None, 90, 2)

# %%
X_train_synth, X_test_synth, y_train_synth, y_test_synth = train_test_split( Xdata_synth, ydata_synth, test_size=0.20, random_state=7)

# %%
def run_model(LSTM_1, LSTM_2, DENSE_1, X_train_synth, y_train_synth, X_test_synth, y_test_synth):

    model = Sequential([
        InputLayer(batch_input_shape=input_shape),
        LSTM(LSTM_1, return_sequences=True),# dropout=0.2), #recurrent_dropout=0.2),
        LSTM(LSTM_2, return_sequences=False),
        Dense(DENSE_1, activation='relu'),
        Dense(3, activation='relu')])

    print(model.summary())

    opt = optimizers.Adam(lr=0.001)

    model.compile(loss='mae', optimizer=opt, metrics=['mae'])
    
    early_stopping = EarlyStopping(patience=5, verbose=1)
    reduce_lr = ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1)
    model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
    #tensorboard = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)

    history_synth = model.fit(X_train_synth, y_train_synth, batch_size=64, epochs=20, 
                          validation_data=(X_test_synth, y_test_synth), 
                          callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=0)
    
    val = history_synth.history['val_loss']
    print(val)
    
    epoch = history_synth.epoch
    loss = history_synth.history['loss']
    val = history_synth.history['val_loss']

    plt.plot(epoch, loss, 'b-')
    plt.plot(epoch, val, 'r.-')
    plt.show()
    
    return val

# in a terminal run:
# tensorboard --logdir ./Graph 
# it gives you access to TensorBoard and how your network is getting trained.

# %%
LSTM_1_space = [50, 100]
LSTM_2_space = [50, 100]
DENSE_1_space = [5, 10, 20]

val_history = np.zeros((3*3*3, 4))

i = 0
for LSTM_1 in LSTM_1_space:
    for LSTM_2 in LSTM_2_space:
        for DENSE_1 in DENSE_1_space:
            print(i)
            val_history[i, :] = [LSTM_1, LSTM_2, DENSE_1, min(run_model(LSTM_1, LSTM_2, DENSE_1, 
                                                                        X_train_synth, y_train_synth, 
                                                                        X_test_synth, y_test_synth))]
            i += 1
# Out:
# 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 255
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 31,073
# Trainable params: 31,073
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.24652, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.24652 to 0.24378, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.24378 to 0.23273, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.23273 to 0.22533, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.22533 to 0.22049, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.22049 to 0.21214, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.21214 to 0.20609, saving model to ./keras.model
#
# Epoch 00008: val_loss improved from 0.20609 to 0.18376, saving model to ./keras.model
#
# Epoch 00009: val_loss improved from 0.18376 to 0.14913, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.14913 to 0.14117, saving model to ./keras.model
#
# Epoch 00011: val_loss improved from 0.14117 to 0.13794, saving model to ./keras.model
#
# Epoch 00012: val_loss improved from 0.13794 to 0.13776, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.13776 to 0.13773, saving model to ./keras.model
#
# Epoch 00014: val_loss improved from 0.13773 to 0.13215, saving model to ./keras.model
#
# Epoch 00015: val_loss improved from 0.13215 to 0.13132, saving model to ./keras.model
#
# Epoch 00016: val_loss improved from 0.13132 to 0.12849, saving model to ./keras.model
#
# Epoch 00017: val_loss did not improve from 0.12849
#
# Epoch 00018: val_loss improved from 0.12849 to 0.12659, saving model to ./keras.model
#
# Epoch 00019: val_loss improved from 0.12659 to 0.12139, saving model to ./keras.model
#
# Epoch 00020: val_loss did not improve from 0.12139
# [0.24652354621887207, 0.24377915716171264, 0.23273307466506957, 0.22533045637607574, 0.2204948103427887, 0.21214487159252166, 0.20608839643001556, 0.1837570927143097, 0.1491281406879425, 0.14116834878921508, 0.13793574535846712, 0.13775863337516786, 0.13772686672210693, 0.13215058660507203, 0.1313214260339737, 0.1284940174818039, 0.13595042932033538, 0.1265863047838211, 0.12139342391490936, 0.12199758732318879]
# 1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 31,343
# Trainable params: 31,343
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.18855, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.18855 to 0.15490, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.15490 to 0.14041, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.14041 to 0.13691, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.13691 to 0.13604, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.13604 to 0.13500, saving model to ./keras.model
#
# Epoch 00007: val_loss did not improve from 0.13500
#
# Epoch 00008: val_loss improved from 0.13500 to 0.12370, saving model to ./keras.model
#
# Epoch 00009: val_loss improved from 0.12370 to 0.11855, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.11855 to 0.11547, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.11547
#
# Epoch 00012: val_loss improved from 0.11547 to 0.10934, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.10934 to 0.10538, saving model to ./keras.model
#
# Epoch 00014: val_loss did not improve from 0.10538
#
# Epoch 00015: val_loss improved from 0.10538 to 0.10308, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.10308
#
# Epoch 00017: val_loss did not improve from 0.10308
#
# Epoch 00018: val_loss did not improve from 0.10308
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_loss improved from 0.10308 to 0.09894, saving model to ./keras.model
#
# Epoch 00020: val_loss improved from 0.09894 to 0.09671, saving model to ./keras.model
# [0.18855419850349425, 0.15490035104751587, 0.14041306602954864, 0.1369050751924515, 0.1360419611930847, 0.13499953413009644, 0.135102282166481, 0.12369782710075379, 0.11855032801628113, 0.11546988785266876, 0.12249134165048599, 0.10934344387054443, 0.10538262832164765, 0.10777576756477356, 0.10307863730192185, 0.11614837580919266, 0.10574923944473266, 0.1079720641374588, 0.0989435954093933, 0.096707983314991]
# 2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 63
# =================================================================
# Total params: 31,883
# Trainable params: 31,883
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.20084, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.20084 to 0.14891, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.14891 to 0.13821, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.13821 to 0.13178, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.13178 to 0.12809, saving model to ./keras.model
#
# Epoch 00006: val_loss did not improve from 0.12809
#
# Epoch 00007: val_loss improved from 0.12809 to 0.11104, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.11104
#
# Epoch 00009: val_loss improved from 0.11104 to 0.10591, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.10591 to 0.09770, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.09770
#
# Epoch 00012: val_loss did not improve from 0.09770
#
# Epoch 00013: val_loss did not improve from 0.09770
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss improved from 0.09770 to 0.09295, saving model to ./keras.model
#
# Epoch 00015: val_loss improved from 0.09295 to 0.09156, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.09156
#
# Epoch 00017: val_loss did not improve from 0.09156
#
# Epoch 00018: val_loss improved from 0.09156 to 0.09104, saving model to ./keras.model
#
# Epoch 00019: val_loss did not improve from 0.09104
#
# Epoch 00020: val_loss did not improve from 0.09104
# [0.20083803653717042, 0.14891427159309387, 0.13820533990859984, 0.13178093492984772, 0.12809474492073059, 0.1301064497232437, 0.11103931105136872, 0.11599823290109634, 0.10591395163536071, 0.09769691503047943, 0.10371870768070221, 0.10599926698207855, 0.09920353639125824, 0.09295276612043381, 0.09155668544769287, 0.09211978828907012, 0.09255998373031617, 0.09103802090883255, 0.09116217410564423, 0.0910483945608139]
# 3
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 505
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 71,523
# Trainable params: 71,523
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.29129, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.29129 to 0.29036, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.29036 to 0.28537, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.28537 to 0.28081, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.28081 to 0.14891, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.14891 to 0.13853, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.13853 to 0.12720, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.12720
#
# Epoch 00009: val_loss improved from 0.12720 to 0.12091, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.12091 to 0.11438, saving model to ./keras.model
#
# Epoch 00011: val_loss improved from 0.11438 to 0.10754, saving model to ./keras.model
#
# Epoch 00012: val_loss improved from 0.10754 to 0.10266, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.10266 to 0.10107, saving model to ./keras.model
#
# Epoch 00014: val_loss did not improve from 0.10107
#
# Epoch 00015: val_loss improved from 0.10107 to 0.09774, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.09774
#
# Epoch 00017: val_loss did not improve from 0.09774
#
# Epoch 00018: val_loss did not improve from 0.09774
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_loss improved from 0.09774 to 0.09122, saving model to ./keras.model
#
# Epoch 00020: val_loss improved from 0.09122 to 0.09095, saving model to ./keras.model
# [0.29129290986061096, 0.2903619456291199, 0.28536624240875247, 0.2808100461959839, 0.14891311359405518, 0.13853075289726258, 0.12720142030715942, 0.1290983190536499, 0.12090646779537201, 0.1143790248632431, 0.1075370039343834, 0.10265729296207428, 0.10107025063037872, 0.10520373499393464, 0.09773640859127045, 0.09988823771476746, 0.10096290338039399, 0.10617300856113433, 0.09121731656789779, 0.0909528539776802]
# 4
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100)               60400
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1010
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 72,043
# Trainable params: 72,043
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.18295, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.18295 to 0.14558, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.14558 to 0.13832, saving model to ./keras.model
#
# Epoch 00004: val_loss did not improve from 0.13832
#
# Epoch 00005: val_loss improved from 0.13832 to 0.12818, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.12818 to 0.11342, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.11342 to 0.10555, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.10555
#
# Epoch 00009: val_loss improved from 0.10555 to 0.10408, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.10408 to 0.09993, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.09993
#
# Epoch 00012: val_loss improved from 0.09993 to 0.09793, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.09793 to 0.09548, saving model to ./keras.model
#
# Epoch 00014: val_loss did not improve from 0.09548
#
# Epoch 00015: val_loss improved from 0.09548 to 0.09304, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.09304
#
# Epoch 00017: val_loss did not improve from 0.09304
#
# Epoch 00018: val_loss did not improve from 0.09304
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_loss improved from 0.09304 to 0.08554, saving model to ./keras.model
#
# Epoch 00020: val_loss did not improve from 0.08554
# [0.182947660446167, 0.14558104634284974, 0.1383222736120224, 0.14271401357650756, 0.1281844470500946, 0.11342308330535888, 0.10555305981636047, 0.10685283553600311, 0.10408464539051056, 0.0999268423318863, 0.10619943523406983, 0.09793179315328598, 0.09547717100381851, 0.10307338190078735, 0.09303758573532105, 0.09318494671583176, 0.09731106209754944, 0.10260708075761794, 0.0855379489660263, 0.08766303825378417]
# 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 90, 50)            10600
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 100)               60400
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 73,083
# Trainable params: 73,083
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.18484, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.18484 to 0.15168, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.15168 to 0.14527, saving model to ./keras.model
#
# Epoch 00004: val_loss did not improve from 0.14527
#
# Epoch 00005: val_loss improved from 0.14527 to 0.13768, saving model to ./keras.model
#
# Epoch 00006: val_loss did not improve from 0.13768
#
# Epoch 00007: val_loss improved from 0.13768 to 0.13520, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.13520
#
# Epoch 00009: val_loss improved from 0.13520 to 0.13135, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.13135 to 0.12833, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.12833
#
# Epoch 00012: val_loss did not improve from 0.12833
#
# Epoch 00013: val_loss improved from 0.12833 to 0.11748, saving model to ./keras.model
#
# Epoch 00014: val_loss did not improve from 0.11748
#
# Epoch 00015: val_loss improved from 0.11748 to 0.11406, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.11406
#
# Epoch 00017: val_loss improved from 0.11406 to 0.10902, saving model to ./keras.model
#
# Epoch 00018: val_loss improved from 0.10902 to 0.10257, saving model to ./keras.model
#
# Epoch 00019: val_loss did not improve from 0.10257
#
# Epoch 00020: val_loss did not improve from 0.10257
# [0.18484206795692443, 0.15168164372444154, 0.14527270209789275, 0.14823169016838073, 0.1376775962114334, 0.13934537255764007, 0.13519884276390076, 0.1436349265575409, 0.13134577894210817, 0.12833174777030945, 0.1402594040632248, 0.13582128083705902, 0.11748256552219391, 0.12145658314228058, 0.1140630061030388, 0.11857228565216064, 0.10901662611961364, 0.10256897312402725, 0.1055897320508957, 0.10740185391902923]
# 6
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 255
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 18
# =================================================================
# Total params: 71,673
# Trainable params: 71,673
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.23542, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.23542 to 0.20163, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.20163 to 0.19828, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.19828 to 0.19695, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.19695 to 0.19525, saving model to ./keras.model
#
# Epoch 00006: val_loss did not improve from 0.19525
#
# Epoch 00007: val_loss improved from 0.19525 to 0.19413, saving model to ./keras.model
#
# Epoch 00008: val_loss improved from 0.19413 to 0.18968, saving model to ./keras.model
#
# Epoch 00009: val_loss improved from 0.18968 to 0.18019, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.18019 to 0.17513, saving model to ./keras.model
#
# Epoch 00011: val_loss improved from 0.17513 to 0.16313, saving model to ./keras.model
#
# Epoch 00012: val_loss improved from 0.16313 to 0.15337, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.15337 to 0.14781, saving model to ./keras.model
#
# Epoch 00014: val_loss improved from 0.14781 to 0.14366, saving model to ./keras.model
#
# Epoch 00015: val_loss improved from 0.14366 to 0.13982, saving model to ./keras.model
#
# Epoch 00016: val_loss improved from 0.13982 to 0.13777, saving model to ./keras.model
#
# Epoch 00017: val_loss improved from 0.13777 to 0.13661, saving model to ./keras.model
#
# Epoch 00018: val_loss did not improve from 0.13661
#
# Epoch 00019: val_loss improved from 0.13661 to 0.13398, saving model to ./keras.model
#
# Epoch 00020: val_loss improved from 0.13398 to 0.13212, saving model to ./keras.model
# [0.23541653978824614, 0.20162614345550536, 0.19828121733665466, 0.19695483553409576, 0.19525388503074645, 0.19591312646865844, 0.19413213729858397, 0.1896761189699173, 0.1801946258544922, 0.17513059258460997, 0.16312718605995177, 0.153367378950119, 0.147805406332016, 0.14365919876098632, 0.13982454764842986, 0.1377716683149338, 0.13661014544963837, 0.139501220703125, 0.13397582423686982, 0.1321163500547409]
# 7
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                510
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 71,943
# Trainable params: 71,943
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.15804, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.15804 to 0.13842, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.13842 to 0.13364, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.13364 to 0.12614, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.12614 to 0.10855, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.10855 to 0.10640, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.10640 to 0.09856, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.09856
#
# Epoch 00009: val_loss did not improve from 0.09856
#
# Epoch 00010: val_loss improved from 0.09856 to 0.09711, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.09711
#
# Epoch 00012: val_loss improved from 0.09711 to 0.09710, saving model to ./keras.model
#
# Epoch 00013: val_loss improved from 0.09710 to 0.09371, saving model to ./keras.model
#
# Epoch 00014: val_loss did not improve from 0.09371
#
# Epoch 00015: val_loss improved from 0.09371 to 0.09335, saving model to ./keras.model
#
# Epoch 00016: val_loss did not improve from 0.09335
#
# Epoch 00017: val_loss improved from 0.09335 to 0.09179, saving model to ./keras.model
#
# Epoch 00018: val_loss did not improve from 0.09179
#
# Epoch 00019: val_loss did not improve from 0.09179
#
# Epoch 00020: val_loss did not improve from 0.09179
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# [0.15803706765174866, 0.13841750288009644, 0.133640696644783, 0.1261433438062668, 0.10855005478858948, 0.10640169298648834, 0.09855633270740509, 0.10003737890720367, 0.10599701911211014, 0.09711222195625305, 0.09900480806827545, 0.09709528851509094, 0.09370818972587586, 0.10020462870597839, 0.09334634882211686, 0.09676718401908875, 0.09178732311725617, 0.09243102645874024, 0.09291116094589233, 0.0920418935418129]
# 8
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_17 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 72,483
# Trainable params: 72,483
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.17761, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.17761 to 0.14533, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.14533 to 0.13355, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.13355 to 0.12796, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.12796 to 0.11873, saving model to ./keras.model
#
# Epoch 00006: val_loss did not improve from 0.11873
#
# Epoch 00007: val_loss improved from 0.11873 to 0.10516, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.10516
#
# Epoch 00009: val_loss improved from 0.10516 to 0.10421, saving model to ./keras.model
#
# Epoch 00010: val_loss did not improve from 0.10421
#
# Epoch 00011: val_loss improved from 0.10421 to 0.09691, saving model to ./keras.model
#
# Epoch 00012: val_loss did not improve from 0.09691
#
# Epoch 00013: val_loss did not improve from 0.09691
#
# Epoch 00014: val_loss improved from 0.09691 to 0.09647, saving model to ./keras.model
#
# Epoch 00015: val_loss did not improve from 0.09647
#
# Epoch 00016: val_loss did not improve from 0.09647
#
# Epoch 00017: val_loss improved from 0.09647 to 0.09452, saving model to ./keras.model
#
# Epoch 00018: val_loss did not improve from 0.09452
#
# Epoch 00019: val_loss did not improve from 0.09452
#
# Epoch 00020: val_loss did not improve from 0.09452
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# [0.1776123502254486, 0.14532869482040406, 0.13355448520183563, 0.12796182668209075, 0.11873193550109863, 0.1388821268081665, 0.10515858316421509, 0.11491996467113495, 0.10421130162477493, 0.11027921885251998, 0.0969052973985672, 0.10110711318254471, 0.10261992406845093, 0.0964677340388298, 0.10983544892072677, 0.09925102031230927, 0.09452205187082291, 0.10377335035800934, 0.09667082870006562, 0.10043501269817352]
# 9
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 505
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 18
# =================================================================
# Total params: 122,123
# Trainable params: 122,123
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.21041, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.21041 to 0.18269, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.18269 to 0.14689, saving model to ./keras.model
#
# Epoch 00004: val_loss improved from 0.14689 to 0.13733, saving model to ./keras.model
#
# Epoch 00005: val_loss improved from 0.13733 to 0.13288, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.13288 to 0.13182, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.13182 to 0.11595, saving model to ./keras.model
#
# Epoch 00008: val_loss improved from 0.11595 to 0.11109, saving model to ./keras.model
#
# Epoch 00009: val_loss improved from 0.11109 to 0.10545, saving model to ./keras.model
#
# Epoch 00010: val_loss improved from 0.10545 to 0.09998, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.09998
#
# Epoch 00012: val_loss did not improve from 0.09998
#
# Epoch 00013: val_loss did not improve from 0.09998
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss improved from 0.09998 to 0.09061, saving model to ./keras.model
#
# Epoch 00015: val_loss did not improve from 0.09061
#
# Epoch 00016: val_loss improved from 0.09061 to 0.08981, saving model to ./keras.model
#
# Epoch 00017: val_loss improved from 0.08981 to 0.08902, saving model to ./keras.model
#
# Epoch 00018: val_loss improved from 0.08902 to 0.08852, saving model to ./keras.model
#
# Epoch 00019: val_loss improved from 0.08852 to 0.08793, saving model to ./keras.model
#
# Epoch 00020: val_loss improved from 0.08793 to 0.08777, saving model to ./keras.model
# [0.21040519857406617, 0.1826924560070038, 0.146893657207489, 0.13732638680934905, 0.13287786161899567, 0.1318163764476776, 0.11595289587974549, 0.11109223967790603, 0.10544737470149994, 0.0999832815527916, 0.10196128416061401, 0.10241191339492797, 0.10096940737962723, 0.0906110416650772, 0.09072367298603058, 0.08980821722745895, 0.08901935052871704, 0.08851945888996124, 0.0879284645318985, 0.08776868391036988]
# 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_21 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                1010
# _________________________________________________________________
# dense_22 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 122,643
# Trainable params: 122,643
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.16982, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.16982 to 0.13800, saving model to ./keras.model
#
# Epoch 00003: val_loss improved from 0.13800 to 0.13300, saving model to ./keras.model
#
# Epoch 00004: val_loss did not improve from 0.13300
#
# Epoch 00005: val_loss improved from 0.13300 to 0.12571, saving model to ./keras.model
#
# Epoch 00006: val_loss improved from 0.12571 to 0.11435, saving model to ./keras.model
#
# Epoch 00007: val_loss improved from 0.11435 to 0.10362, saving model to ./keras.model
#
# Epoch 00008: val_loss did not improve from 0.10362
#
# Epoch 00009: val_loss did not improve from 0.10362
#
# Epoch 00010: val_loss improved from 0.10362 to 0.09773, saving model to ./keras.model
#
# Epoch 00011: val_loss did not improve from 0.09773
#
# Epoch 00012: val_loss improved from 0.09773 to 0.09469, saving model to ./keras.model
#
# Epoch 00013: val_loss did not improve from 0.09469
#
# Epoch 00014: val_loss did not improve from 0.09469
#
# Epoch 00015: val_loss did not improve from 0.09469
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00016: val_loss improved from 0.09469 to 0.08765, saving model to ./keras.model
#
# Epoch 00017: val_loss did not improve from 0.08765
#
# Epoch 00018: val_loss improved from 0.08765 to 0.08758, saving model to ./keras.model
#
# Epoch 00019: val_loss improved from 0.08758 to 0.08673, saving model to ./keras.model
#
# Epoch 00020: val_loss improved from 0.08673 to 0.08567, saving model to ./keras.model
# [0.16981515765190125, 0.1379983298778534, 0.13300210726261139, 0.14786629688739777, 0.12570930671691893, 0.11435242938995362, 0.10361764705181122, 0.10447181677818299, 0.1041448512673378, 0.09772835379838943, 0.10188328528404236, 0.09469299900531769, 0.10528840202093125, 0.09658774411678314, 0.10033754897117615, 0.08765267217159271, 0.08849805003404618, 0.08758442747592926, 0.08673052883148194, 0.0856742816567421]
# 11
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_23 (LSTM)               (None, 90, 100)           41200
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_24 (Dense)             (None, 3)                 63
# =================================================================
# Total params: 123,683
# Trainable params: 123,683
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 0.20091, saving model to ./keras.model
#
# Epoch 00002: val_loss improved from 0.20091 to 0.17904, saving model to ./keras.model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-76cc70c5ae0c> in <module>()
#      12             val_history[i, :] = [LSTM_1, LSTM_2, DENSE_1, min(run_model(LSTM_1, LSTM_2, DENSE_1,
#      13                                                                         X_train_synth, y_train_synth,
# ---> 14                                                                         X_test_synth, y_test_synth))]
#      15             i += 1
#
# <ipython-input-36-310eaf44c733> in run_model(LSTM_1, LSTM_2, DENSE_1, X_train_synth, y_train_synth, X_test_synth, y_test_synth)
#      21     history_synth = model.fit(X_train_synth, y_train_synth, batch_size=64, epochs=20,
#      22                           validation_data=(X_test_synth, y_test_synth),
# ---> 23                           callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=0)
#      24
#      25     val = history_synth.history['val_loss']
#
# /Users/tamiminaser/anaconda/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /Users/tamiminaser/anaconda/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /Users/tamiminaser/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /Users/tamiminaser/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /Users/tamiminaser/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Two promistion models are:
#
# Model 1: LSTM_1(50), LSTM_2(50), DENSE_1(10)
#
# Model 2: LSTM_1(100), LSTM_2(100), DENSE_1(10)
#
# I chose Model 1 because it has about 31,000 total params instead of 122,000

# %%
LSTM_1 = 50
LSTM_2 = 50
DENSE_1 = 10

model = Sequential([InputLayer(batch_input_shape=input_shape),
                    LSTM(LSTM_1, return_sequences=True),# dropout=0.2), #recurrent_dropout=0.2),
                    LSTM(LSTM_2, return_sequences=False),
                    Dense(DENSE_1, activation='relu'),
                    Dense(3, activation='relu')])

print(model.summary())

opt = optimizers.Adam(lr=0.001)

model.compile(loss='mae', optimizer=opt, metrics=['mae'])
    
early_stopping = EarlyStopping(patience=5, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
#tensorboard = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)

history_synth = model.fit(X_train_synth, y_train_synth, batch_size=64, epochs=40, 
                          validation_data=(X_test_synth, y_test_synth), 
                          callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)

    
epoch = history_synth.epoch
loss = history_synth.history['loss']
val = history_synth.history['val_loss']

plt.plot(epoch, loss, 'b-')
plt.plot(epoch, val, 'r.-')
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_35 (LSTM)               (None, 90, 50)            10600
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                510
# _________________________________________________________________
# dense_36 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 31,343
# Trainable params: 31,343
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 16000 samples, validate on 4000 samples
# Epoch 1/40
#  - 87s - loss: 0.3154 - mean_absolute_error: 0.3154 - val_loss: 0.2132 - val_mean_absolute_error: 0.2132
#
# Epoch 00001: val_loss improved from inf to 0.21322, saving model to ./keras.model
# Epoch 2/40
#  - 42s - loss: 0.1838 - mean_absolute_error: 0.1838 - val_loss: 0.1758 - val_mean_absolute_error: 0.1758
#
# Epoch 00002: val_loss improved from 0.21322 to 0.17583, saving model to ./keras.model
# Epoch 3/40
#  - 43s - loss: 0.1527 - mean_absolute_error: 0.1527 - val_loss: 0.1494 - val_mean_absolute_error: 0.1494
#
# Epoch 00003: val_loss improved from 0.17583 to 0.14936, saving model to ./keras.model
# Epoch 4/40
#  - 42s - loss: 0.1454 - mean_absolute_error: 0.1454 - val_loss: 0.1426 - val_mean_absolute_error: 0.1426
#
# Epoch 00004: val_loss improved from 0.14936 to 0.14264, saving model to ./keras.model
# Epoch 5/40
#  - 43s - loss: 0.1411 - mean_absolute_error: 0.1411 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
#
# Epoch 00005: val_loss improved from 0.14264 to 0.14112, saving model to ./keras.model
# Epoch 6/40
#  - 41s - loss: 0.1399 - mean_absolute_error: 0.1399 - val_loss: 0.1372 - val_mean_absolute_error: 0.1372
#
# Epoch 00006: val_loss improved from 0.14112 to 0.13722, saving model to ./keras.model
# Epoch 7/40
#  - 42s - loss: 0.1381 - mean_absolute_error: 0.1381 - val_loss: 0.1353 - val_mean_absolute_error: 0.1353
#
# Epoch 00007: val_loss improved from 0.13722 to 0.13526, saving model to ./keras.model
# Epoch 8/40
#  - 43s - loss: 0.1360 - mean_absolute_error: 0.1360 - val_loss: 0.1345 - val_mean_absolute_error: 0.1345
#
# Epoch 00008: val_loss improved from 0.13526 to 0.13446, saving model to ./keras.model
# Epoch 9/40
#  - 41s - loss: 0.1348 - mean_absolute_error: 0.1348 - val_loss: 0.1312 - val_mean_absolute_error: 0.1312
#
# Epoch 00009: val_loss improved from 0.13446 to 0.13122, saving model to ./keras.model
# Epoch 10/40
#  - 41s - loss: 0.1332 - mean_absolute_error: 0.1332 - val_loss: 0.1283 - val_mean_absolute_error: 0.1283
#
# Epoch 00010: val_loss improved from 0.13122 to 0.12831, saving model to ./keras.model
# Epoch 11/40
#  - 41s - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1254 - val_mean_absolute_error: 0.1254
#
# Epoch 00011: val_loss improved from 0.12831 to 0.12540, saving model to ./keras.model
# Epoch 12/40
#  - 41s - loss: 0.1273 - mean_absolute_error: 0.1273 - val_loss: 0.1254 - val_mean_absolute_error: 0.1254
#
# Epoch 00012: val_loss improved from 0.12540 to 0.12538, saving model to ./keras.model
# Epoch 13/40
#  - 41s - loss: 0.1222 - mean_absolute_error: 0.1222 - val_loss: 0.1128 - val_mean_absolute_error: 0.1128
#
# Epoch 00013: val_loss improved from 0.12538 to 0.11277, saving model to ./keras.model
# Epoch 14/40
#  - 41s - loss: 0.1175 - mean_absolute_error: 0.1175 - val_loss: 0.1253 - val_mean_absolute_error: 0.1253
#
# Epoch 00014: val_loss did not improve from 0.11277
# Epoch 15/40
#  - 41s - loss: 0.1136 - mean_absolute_error: 0.1136 - val_loss: 0.1132 - val_mean_absolute_error: 0.1132
#
# Epoch 00015: val_loss did not improve from 0.11277
# Epoch 16/40
#  - 41s - loss: 0.1088 - mean_absolute_error: 0.1088 - val_loss: 0.1263 - val_mean_absolute_error: 0.1263
#
# Epoch 00016: val_loss did not improve from 0.11277
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/40
#  - 41s - loss: 0.1003 - mean_absolute_error: 0.1003 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
#
# Epoch 00017: val_loss improved from 0.11277 to 0.09643, saving model to ./keras.model
# Epoch 18/40
#  - 41s - loss: 0.0979 - mean_absolute_error: 0.0979 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
#
# Epoch 00018: val_loss improved from 0.09643 to 0.09566, saving model to ./keras.model
# Epoch 19/40
#  - 41s - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.0966 - val_mean_absolute_error: 0.0966
#
# Epoch 00019: val_loss did not improve from 0.09566
# Epoch 20/40
#  - 41s - loss: 0.0971 - mean_absolute_error: 0.0971 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
#
# Epoch 00020: val_loss improved from 0.09566 to 0.09512, saving model to ./keras.model
# Epoch 21/40
#  - 41s - loss: 0.0965 - mean_absolute_error: 0.0965 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
#
# Epoch 00021: val_loss did not improve from 0.09512
# Epoch 22/40
#  - 42s - loss: 0.0963 - mean_absolute_error: 0.0963 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
#
# Epoch 00022: val_loss improved from 0.09512 to 0.09407, saving model to ./keras.model
# Epoch 23/40
#  - 42s - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.0938 - val_mean_absolute_error: 0.0938
#
# Epoch 00023: val_loss improved from 0.09407 to 0.09379, saving model to ./keras.model
# Epoch 24/40
#  - 42s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
#
# Epoch 00024: val_loss did not improve from 0.09379
# Epoch 25/40
#  - 42s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
#
# Epoch 00025: val_loss did not improve from 0.09379
# Epoch 26/40
#  - 41s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
#
# Epoch 00026: val_loss did not improve from 0.09379
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 27/40
#  - 42s - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.0927 - val_mean_absolute_error: 0.0927
#
# Epoch 00027: val_loss improved from 0.09379 to 0.09274, saving model to ./keras.model
# Epoch 28/40
#  - 41s - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.0927 - val_mean_absolute_error: 0.0927
#
# Epoch 00028: val_loss improved from 0.09274 to 0.09266, saving model to ./keras.model
# Epoch 29/40
#  - 41s - loss: 0.0935 - mean_absolute_error: 0.0935 - val_loss: 0.0925 - val_mean_absolute_error: 0.0925
#
# Epoch 00029: val_loss improved from 0.09266 to 0.09250, saving model to ./keras.model
# Epoch 30/40
#  - 42s - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.0925 - val_mean_absolute_error: 0.0925
#
# Epoch 00030: val_loss did not improve from 0.09250
# Epoch 31/40
#  - 42s - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924
#
# Epoch 00031: val_loss improved from 0.09250 to 0.09245, saving model to ./keras.model
# Epoch 32/40
#  - 41s - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924
#
# Epoch 00032: val_loss did not improve from 0.09245
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 33/40
#  - 41s - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.0927 - val_mean_absolute_error: 0.0927
#
# Epoch 00033: val_loss did not improve from 0.09245
# Epoch 34/40
#  - 41s - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924
#
# Epoch 00034: val_loss improved from 0.09245 to 0.09237, saving model to ./keras.model
# Epoch 35/40
#  - 41s - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
#
# Epoch 00035: val_loss improved from 0.09237 to 0.09233, saving model to ./keras.model
# Epoch 36/40
#  - 42s - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
#
# Epoch 00036: val_loss improved from 0.09233 to 0.09230, saving model to ./keras.model
# Epoch 37/40
#  - 41s - loss: 0.0932 - mean_absolute_error: 0.0932 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
# Epoch 00037: val_loss did not improve from 0.09230
# Epoch 38/40
#  - 41s - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924
#
# Epoch 00038: val_loss did not improve from 0.09230
# Epoch 39/40
#  - 42s - loss: 0.0932 - mean_absolute_error: 0.0932 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
#
# Epoch 00039: val_loss did not improve from 0.09230
# Epoch 40/40
#  - 42s - loss: 0.0931 - mean_absolute_error: 0.0931 - val_loss: 0.0922 - val_mean_absolute_error: 0.0922
#
# Epoch 00040: val_loss improved from 0.09230 to 0.09224, saving model to ./keras.model

# %%
X_train, X_test, y_train, y_test = train_test_split( Xdata, ydata, test_size=0.20, random_state=7)
X_train.shape
# Out:
# (283, 90, 2)

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, batch_size=16, epochs=100, 
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)
# Out:
# Train on 283 samples, validate on 71 samples
# Epoch 1/100
#  - 3s - loss: 0.2439 - mean_absolute_error: 0.2439 - val_loss: 0.1705 - val_mean_absolute_error: 0.1705
#
# Epoch 00001: val_loss improved from inf to 0.17046, saving model to ./keras.model
# Epoch 2/100
#  - 3s - loss: 0.2317 - mean_absolute_error: 0.2317 - val_loss: 0.1621 - val_mean_absolute_error: 0.1621
#
# Epoch 00002: val_loss improved from 0.17046 to 0.16206, saving model to ./keras.model
# Epoch 3/100
#  - 3s - loss: 0.2241 - mean_absolute_error: 0.2241 - val_loss: 0.1555 - val_mean_absolute_error: 0.1555
#
# Epoch 00003: val_loss improved from 0.16206 to 0.15549, saving model to ./keras.model
# Epoch 4/100
#  - 3s - loss: 0.2184 - mean_absolute_error: 0.2184 - val_loss: 0.1507 - val_mean_absolute_error: 0.1507
#
# Epoch 00004: val_loss improved from 0.15549 to 0.15066, saving model to ./keras.model
# Epoch 5/100
#  - 3s - loss: 0.2144 - mean_absolute_error: 0.2144 - val_loss: 0.1473 - val_mean_absolute_error: 0.1473
#
# Epoch 00005: val_loss improved from 0.15066 to 0.14725, saving model to ./keras.model
# Epoch 6/100
#  - 3s - loss: 0.2112 - mean_absolute_error: 0.2112 - val_loss: 0.1427 - val_mean_absolute_error: 0.1427
#
# Epoch 00006: val_loss improved from 0.14725 to 0.14274, saving model to ./keras.model
# Epoch 7/100
#  - 3s - loss: 0.2085 - mean_absolute_error: 0.2085 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
#
# Epoch 00007: val_loss improved from 0.14274 to 0.14001, saving model to ./keras.model
# Epoch 8/100
#  - 3s - loss: 0.2060 - mean_absolute_error: 0.2060 - val_loss: 0.1374 - val_mean_absolute_error: 0.1374
#
# Epoch 00008: val_loss improved from 0.14001 to 0.13740, saving model to ./keras.model
# Epoch 9/100
#  - 3s - loss: 0.2042 - mean_absolute_error: 0.2042 - val_loss: 0.1363 - val_mean_absolute_error: 0.1363
#
# Epoch 00009: val_loss improved from 0.13740 to 0.13627, saving model to ./keras.model
# Epoch 10/100
#  - 3s - loss: 0.2024 - mean_absolute_error: 0.2024 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
#
# Epoch 00010: val_loss improved from 0.13627 to 0.13228, saving model to ./keras.model
# Epoch 11/100
#  - 3s - loss: 0.2007 - mean_absolute_error: 0.2007 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
#
# Epoch 00011: val_loss improved from 0.13228 to 0.13199, saving model to ./keras.model
# Epoch 12/100
#  - 3s - loss: 0.1994 - mean_absolute_error: 0.1994 - val_loss: 0.1307 - val_mean_absolute_error: 0.1307
#
# Epoch 00012: val_loss improved from 0.13199 to 0.13074, saving model to ./keras.model
# Epoch 13/100
#  - 3s - loss: 0.1981 - mean_absolute_error: 0.1981 - val_loss: 0.1297 - val_mean_absolute_error: 0.1297
#
# Epoch 00013: val_loss improved from 0.13074 to 0.12968, saving model to ./keras.model
# Epoch 14/100
#  - 3s - loss: 0.1969 - mean_absolute_error: 0.1969 - val_loss: 0.1279 - val_mean_absolute_error: 0.1279
#
# Epoch 00014: val_loss improved from 0.12968 to 0.12794, saving model to ./keras.model
# Epoch 15/100
#  - 3s - loss: 0.1959 - mean_absolute_error: 0.1959 - val_loss: 0.1273 - val_mean_absolute_error: 0.1273
#
# Epoch 00015: val_loss improved from 0.12794 to 0.12734, saving model to ./keras.model
# Epoch 16/100
#  - 3s - loss: 0.1949 - mean_absolute_error: 0.1949 - val_loss: 0.1260 - val_mean_absolute_error: 0.1260
#
# Epoch 00016: val_loss improved from 0.12734 to 0.12596, saving model to ./keras.model
# Epoch 17/100
#  - 3s - loss: 0.1940 - mean_absolute_error: 0.1940 - val_loss: 0.1255 - val_mean_absolute_error: 0.1255
#
# Epoch 00017: val_loss improved from 0.12596 to 0.12551, saving model to ./keras.model
# Epoch 18/100
#  - 3s - loss: 0.1932 - mean_absolute_error: 0.1932 - val_loss: 0.1243 - val_mean_absolute_error: 0.1243
#
# Epoch 00018: val_loss improved from 0.12551 to 0.12432, saving model to ./keras.model
# Epoch 19/100
#  - 3s - loss: 0.1926 - mean_absolute_error: 0.1926 - val_loss: 0.1245 - val_mean_absolute_error: 0.1245
#
# Epoch 00019: val_loss did not improve from 0.12432
# Epoch 20/100
#  - 3s - loss: 0.1918 - mean_absolute_error: 0.1918 - val_loss: 0.1236 - val_mean_absolute_error: 0.1236
#
# Epoch 00020: val_loss improved from 0.12432 to 0.12361, saving model to ./keras.model
# Epoch 21/100
#  - 3s - loss: 0.1913 - mean_absolute_error: 0.1913 - val_loss: 0.1232 - val_mean_absolute_error: 0.1232
#
# Epoch 00021: val_loss improved from 0.12361 to 0.12323, saving model to ./keras.model
# Epoch 22/100
#  - 3s - loss: 0.1907 - mean_absolute_error: 0.1907 - val_loss: 0.1234 - val_mean_absolute_error: 0.1234
#
# Epoch 00022: val_loss did not improve from 0.12323
# Epoch 23/100
#  - 3s - loss: 0.1902 - mean_absolute_error: 0.1902 - val_loss: 0.1228 - val_mean_absolute_error: 0.1228
#
# Epoch 00023: val_loss improved from 0.12323 to 0.12277, saving model to ./keras.model
# Epoch 24/100
#  - 3s - loss: 0.1896 - mean_absolute_error: 0.1896 - val_loss: 0.1225 - val_mean_absolute_error: 0.1225
#
# Epoch 00024: val_loss improved from 0.12277 to 0.12251, saving model to ./keras.model
# Epoch 25/100
#  - 3s - loss: 0.1892 - mean_absolute_error: 0.1892 - val_loss: 0.1226 - val_mean_absolute_error: 0.1226
#
# Epoch 00025: val_loss did not improve from 0.12251
# Epoch 26/100
#  - 3s - loss: 0.1886 - mean_absolute_error: 0.1886 - val_loss: 0.1227 - val_mean_absolute_error: 0.1227
#
# Epoch 00026: val_loss did not improve from 0.12251
# Epoch 27/100
#  - 3s - loss: 0.1882 - mean_absolute_error: 0.1882 - val_loss: 0.1227 - val_mean_absolute_error: 0.1227
#
# Epoch 00027: val_loss did not improve from 0.12251
# Epoch 28/100
#  - 3s - loss: 0.1878 - mean_absolute_error: 0.1878 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
#
# Epoch 00028: val_loss improved from 0.12251 to 0.12194, saving model to ./keras.model
# Epoch 29/100
#  - 3s - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 0.1218 - val_mean_absolute_error: 0.1218
#
# Epoch 00029: val_loss improved from 0.12194 to 0.12181, saving model to ./keras.model
# Epoch 30/100
#  - 3s - loss: 0.1870 - mean_absolute_error: 0.1870 - val_loss: 0.1224 - val_mean_absolute_error: 0.1224
#
# Epoch 00030: val_loss did not improve from 0.12181
# Epoch 31/100
#  - 3s - loss: 0.1866 - mean_absolute_error: 0.1866 - val_loss: 0.1220 - val_mean_absolute_error: 0.1220
#
# Epoch 00031: val_loss did not improve from 0.12181
# Epoch 32/100
#  - 3s - loss: 0.1862 - mean_absolute_error: 0.1862 - val_loss: 0.1217 - val_mean_absolute_error: 0.1217
#
# Epoch 00032: val_loss improved from 0.12181 to 0.12167, saving model to ./keras.model
# Epoch 33/100
#  - 3s - loss: 0.1859 - mean_absolute_error: 0.1859 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
#
# Epoch 00033: val_loss did not improve from 0.12167
# Epoch 34/100
#  - 3s - loss: 0.1856 - mean_absolute_error: 0.1856 - val_loss: 0.1213 - val_mean_absolute_error: 0.1213
#
# Epoch 00034: val_loss improved from 0.12167 to 0.12128, saving model to ./keras.model
# Epoch 35/100
#  - 3s - loss: 0.1852 - mean_absolute_error: 0.1852 - val_loss: 0.1218 - val_mean_absolute_error: 0.1218
#
# Epoch 00035: val_loss did not improve from 0.12128
# Epoch 36/100
#  - 3s - loss: 0.1851 - mean_absolute_error: 0.1851 - val_loss: 0.1215 - val_mean_absolute_error: 0.1215
#
# Epoch 00036: val_loss did not improve from 0.12128
# Epoch 37/100
#  - 3s - loss: 0.1846 - mean_absolute_error: 0.1846 - val_loss: 0.1211 - val_mean_absolute_error: 0.1211
#
# Epoch 00037: val_loss improved from 0.12128 to 0.12105, saving model to ./keras.model
# Epoch 38/100
#  - 3s - loss: 0.1843 - mean_absolute_error: 0.1843 - val_loss: 0.1209 - val_mean_absolute_error: 0.1209
#
# Epoch 00038: val_loss improved from 0.12105 to 0.12088, saving model to ./keras.model
# Epoch 39/100
#  - 3s - loss: 0.1840 - mean_absolute_error: 0.1840 - val_loss: 0.1211 - val_mean_absolute_error: 0.1211
#
# Epoch 00039: val_loss did not improve from 0.12088
# Epoch 40/100
#  - 3s - loss: 0.1838 - mean_absolute_error: 0.1838 - val_loss: 0.1209 - val_mean_absolute_error: 0.1209
#
# Epoch 00040: val_loss did not improve from 0.12088
# Epoch 41/100
#  - 3s - loss: 0.1835 - mean_absolute_error: 0.1835 - val_loss: 0.1211 - val_mean_absolute_error: 0.1211
#
# Epoch 00041: val_loss did not improve from 0.12088
# Epoch 42/100
#  - 3s - loss: 0.1834 - mean_absolute_error: 0.1834 - val_loss: 0.1206 - val_mean_absolute_error: 0.1206
#
# Epoch 00042: val_loss improved from 0.12088 to 0.12064, saving model to ./keras.model
# Epoch 43/100
#  - 3s - loss: 0.1830 - mean_absolute_error: 0.1830 - val_loss: 0.1208 - val_mean_absolute_error: 0.1208
# Epoch 00043: val_loss did not improve from 0.12064
# Epoch 44/100
#  - 3s - loss: 0.1827 - mean_absolute_error: 0.1827 - val_loss: 0.1206 - val_mean_absolute_error: 0.1206
#
# Epoch 00044: val_loss improved from 0.12064 to 0.12061, saving model to ./keras.model
# Epoch 45/100
#  - 3s - loss: 0.1825 - mean_absolute_error: 0.1825 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00045: val_loss did not improve from 0.12061
# Epoch 46/100
#  - 3s - loss: 0.1823 - mean_absolute_error: 0.1823 - val_loss: 0.1208 - val_mean_absolute_error: 0.1208
#
# Epoch 00046: val_loss did not improve from 0.12061
# Epoch 47/100
#  - 3s - loss: 0.1820 - mean_absolute_error: 0.1820 - val_loss: 0.1204 - val_mean_absolute_error: 0.1204
#
# Epoch 00047: val_loss improved from 0.12061 to 0.12042, saving model to ./keras.model
# Epoch 48/100
#  - 3s - loss: 0.1819 - mean_absolute_error: 0.1819 - val_loss: 0.1204 - val_mean_absolute_error: 0.1204
#
# Epoch 00048: val_loss did not improve from 0.12042
# Epoch 49/100
#  - 3s - loss: 0.1818 - mean_absolute_error: 0.1818 - val_loss: 0.1211 - val_mean_absolute_error: 0.1211
#
# Epoch 00049: val_loss did not improve from 0.12042
# Epoch 50/100
#  - 3s - loss: 0.1818 - mean_absolute_error: 0.1818 - val_loss: 0.1201 - val_mean_absolute_error: 0.1201
#
# Epoch 00050: val_loss improved from 0.12042 to 0.12009, saving model to ./keras.model
# Epoch 51/100
#  - 3s - loss: 0.1813 - mean_absolute_error: 0.1813 - val_loss: 0.1215 - val_mean_absolute_error: 0.1215
#
# Epoch 00051: val_loss did not improve from 0.12009
# Epoch 52/100
#  - 3s - loss: 0.1811 - mean_absolute_error: 0.1811 - val_loss: 0.1209 - val_mean_absolute_error: 0.1209
#
# Epoch 00052: val_loss did not improve from 0.12009
# Epoch 53/100
#  - 3s - loss: 0.1809 - mean_absolute_error: 0.1809 - val_loss: 0.1210 - val_mean_absolute_error: 0.1210
#
# Epoch 00053: val_loss did not improve from 0.12009
# Epoch 54/100
#  - 3s - loss: 0.1806 - mean_absolute_error: 0.1806 - val_loss: 0.1208 - val_mean_absolute_error: 0.1208
#
# Epoch 00054: val_loss did not improve from 0.12009
# Epoch 55/100
#  - 3s - loss: 0.1805 - mean_absolute_error: 0.1805 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00055: val_loss did not improve from 0.12009
# Epoch 56/100
#  - 3s - loss: 0.1805 - mean_absolute_error: 0.1805 - val_loss: 0.1210 - val_mean_absolute_error: 0.1210
#
# Epoch 00056: val_loss did not improve from 0.12009
# Epoch 57/100
#  - 3s - loss: 0.1803 - mean_absolute_error: 0.1803 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00057: val_loss did not improve from 0.12009
# Epoch 58/100
#  - 3s - loss: 0.1800 - mean_absolute_error: 0.1800 - val_loss: 0.1214 - val_mean_absolute_error: 0.1214
#
# Epoch 00058: val_loss did not improve from 0.12009
# Epoch 59/100
#  - 3s - loss: 0.1799 - mean_absolute_error: 0.1799 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00059: val_loss did not improve from 0.12009
# Epoch 60/100
#  - 3s - loss: 0.1798 - mean_absolute_error: 0.1798 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216
#
# Epoch 00060: val_loss did not improve from 0.12009
# Epoch 00060: early stopping

# %%
epoch = history.epoch
loss = history.history['loss']
val = history.history['val_loss']

plt.figure(figsize=(8,6))
plt.plot(epoch, loss, 'bx-', label='Training')
plt.plot(epoch, val, 'r.-', label='Validation')
plt.ylim(0.1, 0.4)
plt.xlim(0, 21)
plt.xticks(np.arange(0,21, 2))
plt.title('RNN Model Pre-Trained with Synthetic Data', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('Mean Absolute Error', fontsize=14)
plt.legend()
plt.show()

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)

history2 = model.fit(X_train, y_train, batch_size=16, epochs=20, 
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-8608f7ca2e1d> in <module>
#       5 history2 = model.fit(X_train, y_train, batch_size=16, epochs=20,
#       6                     validation_data=(X_test, y_test),
# ----> 7                     callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     679         if y is not None:
#     680             if not self.optimizer:
# --> 681                 raise RuntimeError('You must compile a model before '
#     682                                    'training/testing. '
#     683                                    'Use `model.compile(optimizer, loss)`.')
#
# RuntimeError: You must compile a model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
epoch = history2.epoch
loss = history2.history['loss']
val = history2.history['val_loss']

plt.figure(figsize=(8,6))
plt.plot(epoch, loss, 'bx-', label='Training')
plt.plot(epoch, val, 'r.-', label='Validation')
plt.ylim(0.1, 0.4)
plt.xlim(0, 21)
plt.xticks(np.arange(0,21, 2))
plt.title('RNN Model Trained with Real Data only', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('Mean Absolute Error', fontsize=14)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-bbc23cc70ba5> in <module>
# ----> 1 epoch = history2.epoch
#       2 loss = history2.history['loss']
#       3 val = history2.history['val_loss']
#       4
#       5 plt.figure(figsize=(8,6))
#
# NameError: name 'history2' is not defined

# %%
q_s_a_init()
# Out:
# array([[1.01002000e+05, 1.00000000e+00, 9.90947311e-01],
#        [1.01002000e+05, 2.00000000e+00, 7.91652282e-01],
#        [1.01002000e+05, 3.00000000e+00, 6.08223947e-01],
#        [1.01002000e+05, 4.00000000e+00, 7.24252207e-02],
#        [1.01002000e+05, 5.00000000e+00, 3.43089178e-01],
#        [1.01002000e+05, 6.00000000e+00, 7.38894636e-01],
#        [1.01004000e+05, 1.00000000e+00, 3.72378961e-01],
#        [1.01004000e+05, 2.00000000e+00, 7.32016551e-01],
#        [1.01004000e+05, 3.00000000e+00, 8.59374253e-01],
#        [1.01004000e+05, 4.00000000e+00, 7.66575025e-01],
#        [1.01004000e+05, 5.00000000e+00, 3.46708058e-03],
#        [1.01004000e+05, 6.00000000e+00, 9.04903006e-01],
#        [1.01006000e+05, 1.00000000e+00, 3.97040167e-01],
#        [1.01006000e+05, 2.00000000e+00, 9.35289309e-01],
#        [1.01006000e+05, 3.00000000e+00, 5.17480205e-01],
#        [1.01006000e+05, 4.00000000e+00, 5.66321720e-01],
#        [1.01006000e+05, 5.00000000e+00, 2.37791498e-01],
#        [1.01006000e+05, 6.00000000e+00, 2.59359786e-03],
#        [1.05002000e+05, 1.00000000e+00, 7.05034105e-01],
#        [1.05002000e+05, 2.00000000e+00, 8.12354818e-01],
#        [1.05002000e+05, 3.00000000e+00, 5.53957031e-01],
#        [1.05002000e+05, 4.00000000e+00, 4.18218431e-01],
#        [1.05002000e+05, 5.00000000e+00, 1.95364910e-01],
#        [1.05002000e+05, 6.00000000e+00, 2.48693601e-02],
#        [1.05004000e+05, 1.00000000e+00, 5.08353396e-01],
#        [1.05004000e+05, 2.00000000e+00, 1.84119763e-02],
#        [1.05004000e+05, 3.00000000e+00, 3.64642685e-01],
#        [1.05004000e+05, 4.00000000e+00, 9.74098232e-01],
#        [1.05004000e+05, 5.00000000e+00, 7.50330490e-01],
#        [1.05004000e+05, 6.00000000e+00, 6.27682548e-01],
#        [1.05006000e+05, 1.00000000e+00, 8.79487230e-01],
#        [1.05006000e+05, 2.00000000e+00, 7.85135292e-01],
#        [1.05006000e+05, 3.00000000e+00, 6.70734230e-01],
#        [1.05006000e+05, 4.00000000e+00, 6.57757826e-01],
#        [1.05006000e+05, 5.00000000e+00, 8.64994036e-01],
#        [1.05006000e+05, 6.00000000e+00, 8.68108954e-01],
#        [1.10002000e+05, 1.00000000e+00, 9.35518298e-01],
#        [1.10002000e+05, 2.00000000e+00, 1.28640171e-01],
#        [1.10002000e+05, 3.00000000e+00, 8.96341409e-01],
#        [1.10002000e+05, 4.00000000e+00, 8.37215515e-02],
#        [1.10002000e+05, 5.00000000e+00, 6.70502848e-01],
#        [1.10002000e+05, 6.00000000e+00, 9.62836178e-01],
#        [1.10004000e+05, 1.00000000e+00, 5.39127688e-01],
#        [1.10004000e+05, 2.00000000e+00, 3.62298916e-01],
#        [1.10004000e+05, 3.00000000e+00, 2.73407590e-01],
#        [1.10004000e+05, 4.00000000e+00, 1.41560793e-01],
#        [1.10004000e+05, 5.00000000e+00, 9.95023584e-01],
#        [1.10004000e+05, 6.00000000e+00, 7.68759403e-01],
#        [1.10006000e+05, 1.00000000e+00, 4.73821313e-02],
#        [1.10006000e+05, 2.00000000e+00, 9.91082178e-01],
#        [1.10006000e+05, 3.00000000e+00, 2.58374115e-01],
#        [1.10006000e+05, 4.00000000e+00, 4.81760707e-02],
#        [1.10006000e+05, 5.00000000e+00, 1.94818707e-01],
#        [1.10006000e+05, 6.00000000e+00, 5.19636668e-02],
#        [5.01002000e+05, 1.00000000e+00, 8.01376444e-01],
#        [5.01002000e+05, 2.00000000e+00, 1.80371268e-01],
#        [5.01002000e+05, 3.00000000e+00, 5.85986608e-01],
#        [5.01002000e+05, 4.00000000e+00, 4.16639690e-01],
#        [5.01002000e+05, 5.00000000e+00, 5.98544755e-01],
#        [5.01002000e+05, 6.00000000e+00, 4.67486617e-01],
#        [5.01004000e+05, 1.00000000e+00, 9.89844255e-01],
#        [5.01004000e+05, 2.00000000e+00, 9.98468247e-01],
#        [5.01004000e+05, 3.00000000e+00, 6.86554655e-01],
#        [5.01004000e+05, 4.00000000e+00, 1.98394943e-02],
#        [5.01004000e+05, 5.00000000e+00, 8.71558458e-01],
#        [5.01004000e+05, 6.00000000e+00, 4.25015744e-01],
#        [5.01006000e+05, 1.00000000e+00, 2.36909103e-01],
#        [5.01006000e+05, 2.00000000e+00, 9.70937179e-01],
#        [5.01006000e+05, 3.00000000e+00, 3.40989104e-01],
#        [5.01006000e+05, 4.00000000e+00, 5.72090070e-01],
#        [5.01006000e+05, 5.00000000e+00, 7.30743014e-01],
#        [5.01006000e+05, 6.00000000e+00, 1.15950695e-01],
#        [5.05002000e+05, 1.00000000e+00, 1.70753324e-01],
#        [5.05002000e+05, 2.00000000e+00, 1.54088580e-01],
#        [5.05002000e+05, 3.00000000e+00, 2.17195193e-01],
#        [5.05002000e+05, 4.00000000e+00, 4.66439765e-01],
#        [5.05002000e+05, 5.00000000e+00, 9.26522862e-01],
#        [5.05002000e+05, 6.00000000e+00, 5.43429947e-01],
#        [5.05004000e+05, 1.00000000e+00, 9.80928252e-01],
#        [5.05004000e+05, 2.00000000e+00, 6.55515262e-01],
#        [5.05004000e+05, 3.00000000e+00, 7.86707389e-01],
#        [5.05004000e+05, 4.00000000e+00, 7.95140911e-01],
#        [5.05004000e+05, 5.00000000e+00, 5.43087275e-01],
#        [5.05004000e+05, 6.00000000e+00, 8.13302920e-01],
#        [5.05006000e+05, 1.00000000e+00, 1.25663629e-01],
#        [5.05006000e+05, 2.00000000e+00, 1.70481245e-01],
#        [5.05006000e+05, 3.00000000e+00, 5.00005331e-01],
#        [5.05006000e+05, 4.00000000e+00, 5.84283877e-01],
#        [5.05006000e+05, 5.00000000e+00, 7.91577522e-01],
#        [5.05006000e+05, 6.00000000e+00, 4.97058834e-01],
#        [5.10002000e+05, 1.00000000e+00, 4.46883783e-01],
#        [5.10002000e+05, 2.00000000e+00, 6.73954898e-02],
#        [5.10002000e+05, 3.00000000e+00, 7.21371841e-01],
#        [5.10002000e+05, 4.00000000e+00, 7.35381877e-01],
#        [5.10002000e+05, 5.00000000e+00, 3.70839721e-01],
#        [5.10002000e+05, 6.00000000e+00, 2.40535751e-01],
#        [5.10004000e+05, 1.00000000e+00, 5.25352885e-01],
#        [5.10004000e+05, 2.00000000e+00, 3.40839556e-01],
#        [5.10004000e+05, 3.00000000e+00, 5.20013301e-02],
#        [5.10004000e+05, 4.00000000e+00, 3.25738515e-01],
#        [5.10004000e+05, 5.00000000e+00, 4.96621862e-01],
#        [5.10004000e+05, 6.00000000e+00, 1.94625845e-01],
#        [5.10006000e+05, 1.00000000e+00, 2.59516070e-01],
#        [5.10006000e+05, 2.00000000e+00, 8.08088299e-01],
#        [5.10006000e+05, 3.00000000e+00, 4.40985939e-01],
#        [5.10006000e+05, 4.00000000e+00, 7.82273705e-01],
#        [5.10006000e+05, 5.00000000e+00, 6.52747578e-01],
#        [5.10006000e+05, 6.00000000e+00, 5.47950878e-01],
#        [1.00100200e+06, 1.00000000e+00, 4.85305987e-01],
#        [1.00100200e+06, 2.00000000e+00, 1.95470627e-01],
#        [1.00100200e+06, 3.00000000e+00, 9.27055595e-01],
#        [1.00100200e+06, 4.00000000e+00, 3.55936932e-01],
#        [1.00100200e+06, 5.00000000e+00, 9.93203042e-01],
#        [1.00100200e+06, 6.00000000e+00, 3.49774738e-01],
#        [1.00100400e+06, 1.00000000e+00, 6.17822452e-01],
#        [1.00100400e+06, 2.00000000e+00, 3.33217303e-01],
#        [1.00100400e+06, 3.00000000e+00, 5.76396511e-01],
#        [1.00100400e+06, 4.00000000e+00, 5.26818252e-01],
#        [1.00100400e+06, 5.00000000e+00, 2.16767608e-01],
#        [1.00100400e+06, 6.00000000e+00, 8.51072715e-01],
#        [1.00100600e+06, 1.00000000e+00, 3.01544195e-03],
#        [1.00100600e+06, 2.00000000e+00, 7.49657554e-01],
#        [1.00100600e+06, 3.00000000e+00, 1.77493943e-01],
#        [1.00100600e+06, 4.00000000e+00, 6.48647969e-01],
#        [1.00100600e+06, 5.00000000e+00, 9.22969836e-01],
#        [1.00100600e+06, 6.00000000e+00, 2.22497040e-01],
#        [1.00500200e+06, 1.00000000e+00, 9.59433975e-01],
#        [1.00500200e+06, 2.00000000e+00, 7.39993481e-01],
#        [1.00500200e+06, 3.00000000e+00, 6.36897974e-01],
#        [1.00500200e+06, 4.00000000e+00, 8.18408147e-01],
#        [1.00500200e+06, 5.00000000e+00, 4.31441846e-01],
#        [1.00500200e+06, 6.00000000e+00, 1.93508383e-01],
#        [1.00500400e+06, 1.00000000e+00, 1.08585592e-01],
#        [1.00500400e+06, 2.00000000e+00, 3.81394415e-02],
#        [1.00500400e+06, 3.00000000e+00, 1.15509615e-01],
#        [1.00500400e+06, 4.00000000e+00, 8.91943989e-01],
#        [1.00500400e+06, 5.00000000e+00, 6.46027761e-01],
#        [1.00500400e+06, 6.00000000e+00, 5.18412122e-01],
#        [1.00500600e+06, 1.00000000e+00, 3.34163513e-01],
#        [1.00500600e+06, 2.00000000e+00, 1.16162324e-01],
#        [1.00500600e+06, 3.00000000e+00, 7.42185759e-01],
#        [1.00500600e+06, 4.00000000e+00, 5.90486404e-01],
#        [1.00500600e+06, 5.00000000e+00, 3.54199735e-01],
#        [1.00500600e+06, 6.00000000e+00, 3.06559912e-01],
#        [1.01000200e+06, 1.00000000e+00, 8.95043189e-01],
#        [1.01000200e+06, 2.00000000e+00, 3.24281181e-01],
#        [1.01000200e+06, 3.00000000e+00, 5.79341153e-01],
#        [1.01000200e+06, 4.00000000e+00, 7.78795937e-02],
#        [1.01000200e+06, 5.00000000e+00, 3.16578119e-01],
#        [1.01000200e+06, 6.00000000e+00, 9.15164792e-01],
#        [1.01000400e+06, 1.00000000e+00, 2.68999714e-01],
#        [1.01000400e+06, 2.00000000e+00, 7.50222098e-01],
#        [1.01000400e+06, 3.00000000e+00, 4.02936448e-01],
#        [1.01000400e+06, 4.00000000e+00, 6.64708139e-01],
#        [1.01000400e+06, 5.00000000e+00, 1.73217849e-01],
#        [1.01000400e+06, 6.00000000e+00, 8.09236302e-01],
#        [1.01000600e+06, 1.00000000e+00, 8.56184942e-01],
#        [1.01000600e+06, 2.00000000e+00, 7.02964651e-01],
#        [1.01000600e+06, 3.00000000e+00, 5.01770586e-01],
#        [1.01000600e+06, 4.00000000e+00, 2.34601116e-01],
#        [1.01000600e+06, 5.00000000e+00, 9.29193961e-02],
#        [1.01000600e+06, 6.00000000e+00, 5.36565914e-01]])
