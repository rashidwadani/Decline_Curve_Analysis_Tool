# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
from time import time

# %%
file_1 = 'Small_Dataset_of_Good_APIs_2.csv'
production_data = pd.read_csv(file_1)

file_2 = './save/All_saved_parameters_20190211194512.csv'
parameters_data = pd.read_csv(file_2)

# %%
min_qi = parameters_data['qi'].quantile(0.05)
max_qi = parameters_data['qi'].quantile(0.95)

min_di = parameters_data['di'].quantile(0.05)
max_di = parameters_data['di'].quantile(0.95)

min_b = parameters_data['b'].quantile(0.05)
max_b = parameters_data['b'].quantile(0.95)

parameters_data['qi_norm'] = (parameters_data['qi']-min_qi)/(max_qi-min_qi)
parameters_data['di_norm'] = (parameters_data['di']-min_di)/(max_di-min_di)
parameters_data['b_norm'] = (parameters_data['b']-min_b)/(max_b-min_b)

# %%
ydata = parameters_data[['qi_norm', 'di_norm', 'b_norm']].as_matrix()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
Xdata = np.zeros(shape=(parameters_data.shape[0], 90, 2))-1

# %%
sample = 0

max_cum_days = 0

for API_NUMBER in parameters_data['API_NUMBER']:
    #print(API_NUMBER, sample)
    selected_production_data = pd.DataFrame()
    selected_production_data = production_data.loc[production_data['API_NUMBER']==API_NUMBER, ['OIL_PROD_DAYS', 'OIL_PRODUCTION_BBL']]
    selected_production_data = selected_production_data.dropna()
    selected_production_data = selected_production_data.loc[selected_production_data['OIL_PRODUCTION_BBL']>0]
    selected_production_data['RATE_PROD'] = selected_production_data['OIL_PRODUCTION_BBL']/selected_production_data['OIL_PROD_DAYS']
    selected_production_data['CUM_DAYS'] = selected_production_data['OIL_PROD_DAYS'].cumsum()
    t = selected_production_data['CUM_DAYS']
    q = selected_production_data['RATE_PROD']
    if (max_cum_days < selected_production_data['CUM_DAYS'].max()):
        max_cum_days = selected_production_data['CUM_DAYS'].max()
    Xdata[sample, 0:t.shape[0], 0] = t
    Xdata[sample, 0:t.shape[0], 1] = q
    sample += 1

# %%
max_month=round(max_cum_days/30)
max_month
# Out:
# 88.0

# %%
def func_hyp(t, qi, di, b):
    return qi/((1+di*b*t)**(1/b))

# %%
number_of_synth_examples = 5000

Xdata_synth = np.zeros(shape=(number_of_synth_examples, 90, 2))-1
ydata_synth = np.zeros(shape=(number_of_synth_examples, 3))

for i in range(number_of_synth_examples):
    #print(i)
    qi_synth = random.uniform(min_qi, max_qi)
    di_synth = random.uniform(min_di, max_di)
    b_synth = random.uniform(min_b, max_b)
    
    qi_synth_norm = (qi_synth-min_qi)/(max_qi-min_qi)
    di_synth_norm = (di_synth-min_di)/(max_di-min_di)
    b_synth_norm = (b_synth-min_b)/(max_b-min_b)
    
    
    ydata_synth[i, :] = [qi_synth_norm, di_synth_norm, b_synth_norm]
    
    cum_months_synth = random.randint(12, max_month)
    start_day_synth = random.randint(5,30)
    
    j=0
    for cum_days_synth in range(start_day_synth, cum_months_synth*30, 30):
        production_noise = random.random()
        production_synth = func_hyp(cum_days_synth, qi_synth, di_synth, b_synth)*(1+production_noise)
        Xdata_synth[i, j, :] = [cum_days_synth, production_synth]
        j += 1

# %%
sample_for_plot = 670

plt.plot(Xdata_synth[sample_for_plot,:,0], Xdata_synth[sample_for_plot,:,1], 'b.')
plt.show()

# %%
import keras
from keras.models import Sequential  
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.layers import InputLayer
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

# %%
input_shape = (None, 90, 2)

# %%
model = Sequential([
    InputLayer(batch_input_shape=input_shape),
    LSTM(50,return_sequences=True),# dropout=0.2), #recurrent_dropout=0.2),
    LSTM(5, return_sequences=False),
    #Dense(10, activation='relu'),
    Dense(3, activation='relu')])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 90, 50)            10600
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5)                 1120
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 11,738
# Trainable params: 11,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = optimizers.Adam(lr=0.001)

model.compile(loss='mae',
          optimizer=opt,
          metrics=['mae'])

# %%
X_train_synth, X_test_synth, y_train_synth, y_test_synth = train_test_split( Xdata_synth, ydata_synth, test_size=0.20, random_state=7)

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)


history_synth = model.fit(X_train_synth, y_train_synth, batch_size=64, epochs=200, 
                          validation_data=(X_test_synth, y_test_synth), 
                          callbacks=[early_stopping, model_checkpoint, reduce_lr, tensorboard], verbose=2)

# in a terminal run:
# tensorboard --logdir ./Graph 
# it gives you access to TensorBoard and how your network is getting trained.
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/200
#  - 5s - loss: 0.4083 - mean_absolute_error: 0.4083 - val_loss: 0.3642 - val_mean_absolute_error: 0.3642
#
# Epoch 00001: val_loss improved from inf to 0.36420, saving model to ./keras.model
# Epoch 2/200
#  - 4s - loss: 0.2623 - mean_absolute_error: 0.2623 - val_loss: 0.2512 - val_mean_absolute_error: 0.2512
#
# Epoch 00002: val_loss improved from 0.36420 to 0.25125, saving model to ./keras.model
# Epoch 3/200
#  - 4s - loss: 0.2510 - mean_absolute_error: 0.2510 - val_loss: 0.2505 - val_mean_absolute_error: 0.2505
#
# Epoch 00003: val_loss improved from 0.25125 to 0.25054, saving model to ./keras.model
# Epoch 4/200
#  - 4s - loss: 0.2505 - mean_absolute_error: 0.2505 - val_loss: 0.2503 - val_mean_absolute_error: 0.2503
#
# Epoch 00004: val_loss improved from 0.25054 to 0.25029, saving model to ./keras.model
# Epoch 5/200
#  - 4s - loss: 0.2505 - mean_absolute_error: 0.2505 - val_loss: 0.2514 - val_mean_absolute_error: 0.2514
#
# Epoch 00005: val_loss did not improve from 0.25029
# Epoch 6/200
#  - 4s - loss: 0.2501 - mean_absolute_error: 0.2501 - val_loss: 0.2481 - val_mean_absolute_error: 0.2481
#
# Epoch 00006: val_loss improved from 0.25029 to 0.24811, saving model to ./keras.model
# Epoch 7/200
#  - 4s - loss: 0.2403 - mean_absolute_error: 0.2403 - val_loss: 0.2280 - val_mean_absolute_error: 0.2280
#
# Epoch 00007: val_loss improved from 0.24811 to 0.22802, saving model to ./keras.model
# Epoch 8/200
#  - 4s - loss: 0.2266 - mean_absolute_error: 0.2266 - val_loss: 0.2128 - val_mean_absolute_error: 0.2128
#
# Epoch 00008: val_loss improved from 0.22802 to 0.21277, saving model to ./keras.model
# Epoch 9/200
#  - 4s - loss: 0.2098 - mean_absolute_error: 0.2098 - val_loss: 0.1918 - val_mean_absolute_error: 0.1918
#
# Epoch 00009: val_loss improved from 0.21277 to 0.19182, saving model to ./keras.model
# Epoch 10/200
#  - 4s - loss: 0.1916 - mean_absolute_error: 0.1916 - val_loss: 0.1763 - val_mean_absolute_error: 0.1763
#
# Epoch 00010: val_loss improved from 0.19182 to 0.17634, saving model to ./keras.model
# Epoch 11/200
#  - 4s - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1659 - val_mean_absolute_error: 0.1659
#
# Epoch 00011: val_loss improved from 0.17634 to 0.16587, saving model to ./keras.model
# Epoch 12/200
#  - 4s - loss: 0.1618 - mean_absolute_error: 0.1618 - val_loss: 0.1554 - val_mean_absolute_error: 0.1554
#
# Epoch 00012: val_loss improved from 0.16587 to 0.15545, saving model to ./keras.model
# Epoch 13/200
#  - 4s - loss: 0.1578 - mean_absolute_error: 0.1578 - val_loss: 0.1561 - val_mean_absolute_error: 0.1561
#
# Epoch 00013: val_loss did not improve from 0.15545
# Epoch 14/200
#  - 4s - loss: 0.1573 - mean_absolute_error: 0.1573 - val_loss: 0.1549 - val_mean_absolute_error: 0.1549
#
# Epoch 00014: val_loss improved from 0.15545 to 0.15493, saving model to ./keras.model
# Epoch 15/200
#  - 4s - loss: 0.1562 - mean_absolute_error: 0.1562 - val_loss: 0.1574 - val_mean_absolute_error: 0.1574
#
# Epoch 00015: val_loss did not improve from 0.15493
# Epoch 16/200
#  - 5s - loss: 0.1531 - mean_absolute_error: 0.1531 - val_loss: 0.1517 - val_mean_absolute_error: 0.1517
#
# Epoch 00016: val_loss improved from 0.15493 to 0.15172, saving model to ./keras.model
# Epoch 17/200
#  - 4s - loss: 0.1545 - mean_absolute_error: 0.1545 - val_loss: 0.1512 - val_mean_absolute_error: 0.1512
#
# Epoch 00017: val_loss improved from 0.15172 to 0.15124, saving model to ./keras.model
# Epoch 18/200
#  - 4s - loss: 0.1521 - mean_absolute_error: 0.1521 - val_loss: 0.1482 - val_mean_absolute_error: 0.1482
#
# Epoch 00018: val_loss improved from 0.15124 to 0.14824, saving model to ./keras.model
# Epoch 19/200
#  - 4s - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.1536 - val_mean_absolute_error: 0.1536
#
# Epoch 00019: val_loss did not improve from 0.14824
# Epoch 20/200
#  - 4s - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 0.1517 - val_mean_absolute_error: 0.1517
#
# Epoch 00020: val_loss did not improve from 0.14824
# Epoch 21/200
#  - 4s - loss: 0.1491 - mean_absolute_error: 0.1491 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450
#
# Epoch 00021: val_loss improved from 0.14824 to 0.14495, saving model to ./keras.model
# Epoch 22/200
#  - 4s - loss: 0.1484 - mean_absolute_error: 0.1484 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457
#
# Epoch 00022: val_loss did not improve from 0.14495
# Epoch 23/200
#  - 4s - loss: 0.1463 - mean_absolute_error: 0.1463 - val_loss: 0.1441 - val_mean_absolute_error: 0.1441
#
# Epoch 00023: val_loss improved from 0.14495 to 0.14412, saving model to ./keras.model
# Epoch 24/200
#  - 4s - loss: 0.1460 - mean_absolute_error: 0.1460 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450
#
# Epoch 00024: val_loss did not improve from 0.14412
# Epoch 25/200
#  - 4s - loss: 0.1451 - mean_absolute_error: 0.1451 - val_loss: 0.1474 - val_mean_absolute_error: 0.1474
#
# Epoch 00025: val_loss did not improve from 0.14412
# Epoch 26/200
#  - 4s - loss: 0.1457 - mean_absolute_error: 0.1457 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428
#
# Epoch 00026: val_loss improved from 0.14412 to 0.14279, saving model to ./keras.model
# Epoch 27/200
#  - 4s - loss: 0.1452 - mean_absolute_error: 0.1452 - val_loss: 0.1425 - val_mean_absolute_error: 0.1425
#
# Epoch 00027: val_loss improved from 0.14279 to 0.14254, saving model to ./keras.model
# Epoch 28/200
#  - 4s - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1477 - val_mean_absolute_error: 0.1477
#
# Epoch 00028: val_loss did not improve from 0.14254
# Epoch 29/200
#  - 4s - loss: 0.1450 - mean_absolute_error: 0.1450 - val_loss: 0.1504 - val_mean_absolute_error: 0.1504
#
# Epoch 00029: val_loss did not improve from 0.14254
# Epoch 30/200
#  - 4s - loss: 0.1420 - mean_absolute_error: 0.1420 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
#
# Epoch 00030: val_loss improved from 0.14254 to 0.14083, saving model to ./keras.model
# Epoch 31/200
#  - 4s - loss: 0.1405 - mean_absolute_error: 0.1405 - val_loss: 0.1380 - val_mean_absolute_error: 0.1380
#
# Epoch 00031: val_loss improved from 0.14083 to 0.13799, saving model to ./keras.model
# Epoch 32/200
#  - 4s - loss: 0.1392 - mean_absolute_error: 0.1392 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
#
# Epoch 00032: val_loss did not improve from 0.13799
# Epoch 33/200
#  - 4s - loss: 0.1380 - mean_absolute_error: 0.1380 - val_loss: 0.1364 - val_mean_absolute_error: 0.1364
#
# Epoch 00033: val_loss improved from 0.13799 to 0.13642, saving model to ./keras.model
# Epoch 34/200
#  - 4s - loss: 0.1400 - mean_absolute_error: 0.1400 - val_loss: 0.1380 - val_mean_absolute_error: 0.1380
#
# Epoch 00034: val_loss did not improve from 0.13642
# Epoch 35/200
#  - 4s - loss: 0.1377 - mean_absolute_error: 0.1377 - val_loss: 0.1377 - val_mean_absolute_error: 0.1377
#
# Epoch 00035: val_loss did not improve from 0.13642
# Epoch 36/200
#  - 4s - loss: 0.1356 - mean_absolute_error: 0.1356 - val_loss: 0.1343 - val_mean_absolute_error: 0.1343
#
# Epoch 00036: val_loss improved from 0.13642 to 0.13429, saving model to ./keras.model
# Epoch 37/200
#  - 4s - loss: 0.1355 - mean_absolute_error: 0.1355 - val_loss: 0.1381 - val_mean_absolute_error: 0.1381
#
# Epoch 00037: val_loss did not improve from 0.13429
# Epoch 38/200
#  - 4s - loss: 0.1367 - mean_absolute_error: 0.1367 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
#
# Epoch 00038: val_loss did not improve from 0.13429
# Epoch 39/200
#  - 4s - loss: 0.1356 - mean_absolute_error: 0.1356 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
#
# Epoch 00039: val_loss improved from 0.13429 to 0.13365, saving model to ./keras.model
# Epoch 40/200
#  - 4s - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355
#
# Epoch 00040: val_loss did not improve from 0.13365
# Epoch 41/200
#  - 4s - loss: 0.1341 - mean_absolute_error: 0.1341 - val_loss: 0.1331 - val_mean_absolute_error: 0.1331
#
# Epoch 00041: val_loss improved from 0.13365 to 0.13312, saving model to ./keras.model
# Epoch 42/200
#  - 4s - loss: 0.1343 - mean_absolute_error: 0.1343 - val_loss: 0.1343 - val_mean_absolute_error: 0.1343
#
# Epoch 00042: val_loss did not improve from 0.13312
# Epoch 43/200
#  - 4s - loss: 0.1324 - mean_absolute_error: 0.1324 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
#
# Epoch 00043: val_loss improved from 0.13312 to 0.13241, saving model to ./keras.model
# Epoch 44/200
#  - 5s - loss: 0.1330 - mean_absolute_error: 0.1330 - val_loss: 0.1316 - val_mean_absolute_error: 0.1316
#
# Epoch 00044: val_loss improved from 0.13241 to 0.13158, saving model to ./keras.model
# Epoch 45/200
#  - 4s - loss: 0.1332 - mean_absolute_error: 0.1332 - val_loss: 0.1280 - val_mean_absolute_error: 0.1280
#
# Epoch 00045: val_loss improved from 0.13158 to 0.12797, saving model to ./keras.model
# Epoch 46/200
#  - 4s - loss: 0.1290 - mean_absolute_error: 0.1290 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
#
# Epoch 00046: val_loss did not improve from 0.12797
# Epoch 47/200
#  - 4s - loss: 0.1326 - mean_absolute_error: 0.1326 - val_loss: 0.1267 - val_mean_absolute_error: 0.1267
#
# Epoch 00047: val_loss improved from 0.12797 to 0.12674, saving model to ./keras.model
# Epoch 48/200
#  - 4s - loss: 0.1279 - mean_absolute_error: 0.1279 - val_loss: 0.1262 - val_mean_absolute_error: 0.1262
#
# Epoch 00048: val_loss improved from 0.12674 to 0.12624, saving model to ./keras.model
# Epoch 49/200
#  - 4s - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1326 - val_mean_absolute_error: 0.1326
#
# Epoch 00049: val_loss did not improve from 0.12624
# Epoch 50/200
#  - 4s - loss: 0.1266 - mean_absolute_error: 0.1266 - val_loss: 0.1255 - val_mean_absolute_error: 0.1255
#
# Epoch 00050: val_loss improved from 0.12624 to 0.12548, saving model to ./keras.model
# Epoch 51/200
#  - 4s - loss: 0.1268 - mean_absolute_error: 0.1268 - val_loss: 0.1247 - val_mean_absolute_error: 0.1247
#
# Epoch 00051: val_loss improved from 0.12548 to 0.12468, saving model to ./keras.model
# Epoch 52/200
#  - 4s - loss: 0.1257 - mean_absolute_error: 0.1257 - val_loss: 0.1257 - val_mean_absolute_error: 0.1257
#
# Epoch 00052: val_loss did not improve from 0.12468
# Epoch 53/200
#  - 4s - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.1235 - val_mean_absolute_error: 0.1235
#
# Epoch 00053: val_loss improved from 0.12468 to 0.12353, saving model to ./keras.model
# Epoch 54/200
#  - 4s - loss: 0.1251 - mean_absolute_error: 0.1251 - val_loss: 0.1225 - val_mean_absolute_error: 0.1225
#
# Epoch 00054: val_loss improved from 0.12353 to 0.12253, saving model to ./keras.model
# Epoch 55/200
#  - 4s - loss: 0.1240 - mean_absolute_error: 0.1240 - val_loss: 0.1271 - val_mean_absolute_error: 0.1271
#
# Epoch 00055: val_loss did not improve from 0.12253
# Epoch 56/200
#  - 4s - loss: 0.1223 - mean_absolute_error: 0.1223 - val_loss: 0.1187 - val_mean_absolute_error: 0.1187
#
# Epoch 00056: val_loss improved from 0.12253 to 0.11867, saving model to ./keras.model
# Epoch 57/200
#  - 4s - loss: 0.1229 - mean_absolute_error: 0.1229 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00057: val_loss did not improve from 0.11867
# Epoch 58/200
#  - 4s - loss: 0.1186 - mean_absolute_error: 0.1186 - val_loss: 0.1354 - val_mean_absolute_error: 0.1354
#
# Epoch 00058: val_loss did not improve from 0.11867
# Epoch 59/200
#  - 4s - loss: 0.1222 - mean_absolute_error: 0.1222 - val_loss: 0.1187 - val_mean_absolute_error: 0.1187
#
# Epoch 00059: val_loss did not improve from 0.11867
# Epoch 60/200
#  - 4s - loss: 0.1206 - mean_absolute_error: 0.1206 - val_loss: 0.1174 - val_mean_absolute_error: 0.1174
#
# Epoch 00060: val_loss improved from 0.11867 to 0.11736, saving model to ./keras.model
# Epoch 61/200
#  - 4s - loss: 0.1146 - mean_absolute_error: 0.1146 - val_loss: 0.1125 - val_mean_absolute_error: 0.1125
#
# Epoch 00061: val_loss improved from 0.11736 to 0.11252, saving model to ./keras.model
# Epoch 62/200
#  - 4s - loss: 0.1195 - mean_absolute_error: 0.1195 - val_loss: 0.1113 - val_mean_absolute_error: 0.1113
#
# Epoch 00062: val_loss improved from 0.11252 to 0.11134, saving model to ./keras.model
# Epoch 63/200
#  - 4s - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.1120 - val_mean_absolute_error: 0.1120
#
# Epoch 00063: val_loss did not improve from 0.11134
# Epoch 64/200
#  - 4s - loss: 0.1161 - mean_absolute_error: 0.1161 - val_loss: 0.1184 - val_mean_absolute_error: 0.1184
#
# Epoch 00064: val_loss did not improve from 0.11134
# Epoch 65/200
#  - 4s - loss: 0.1152 - mean_absolute_error: 0.1152 - val_loss: 0.1158 - val_mean_absolute_error: 0.1158
#
# Epoch 00065: val_loss did not improve from 0.11134
# Epoch 66/200
#  - 4s - loss: 0.1157 - mean_absolute_error: 0.1157 - val_loss: 0.1128 - val_mean_absolute_error: 0.1128
#
# Epoch 00066: val_loss did not improve from 0.11134
# Epoch 67/200
#  - 4s - loss: 0.1126 - mean_absolute_error: 0.1126 - val_loss: 0.1101 - val_mean_absolute_error: 0.1101
#
# Epoch 00067: val_loss improved from 0.11134 to 0.11010, saving model to ./keras.model
# Epoch 68/200
#  - 4s - loss: 0.1118 - mean_absolute_error: 0.1118 - val_loss: 0.1159 - val_mean_absolute_error: 0.1159
#
# Epoch 00068: val_loss did not improve from 0.11010
# Epoch 69/200
#  - 4s - loss: 0.1102 - mean_absolute_error: 0.1102 - val_loss: 0.1138 - val_mean_absolute_error: 0.1138
#
# Epoch 00069: val_loss did not improve from 0.11010
# Epoch 70/200
#  - 4s - loss: 0.1123 - mean_absolute_error: 0.1123 - val_loss: 0.1229 - val_mean_absolute_error: 0.1229
#
# Epoch 00070: val_loss did not improve from 0.11010
# Epoch 71/200
#  - 4s - loss: 0.1118 - mean_absolute_error: 0.1118 - val_loss: 0.1192 - val_mean_absolute_error: 0.1192
#
# Epoch 00071: val_loss did not improve from 0.11010
# Epoch 72/200
#  - 4s - loss: 0.1100 - mean_absolute_error: 0.1100 - val_loss: 0.1091 - val_mean_absolute_error: 0.1091
#
# Epoch 00072: val_loss improved from 0.11010 to 0.10906, saving model to ./keras.model
# Epoch 73/200
#  - 4s - loss: 0.1053 - mean_absolute_error: 0.1053 - val_loss: 0.1095 - val_mean_absolute_error: 0.1095
#
# Epoch 00073: val_loss did not improve from 0.10906
# Epoch 74/200
#  - 4s - loss: 0.1091 - mean_absolute_error: 0.1091 - val_loss: 0.1074 - val_mean_absolute_error: 0.1074
#
# Epoch 00074: val_loss improved from 0.10906 to 0.10737, saving model to ./keras.model
# Epoch 75/200
#  - 4s - loss: 0.1090 - mean_absolute_error: 0.1090 - val_loss: 0.1102 - val_mean_absolute_error: 0.1102
#
# Epoch 00075: val_loss did not improve from 0.10737
# Epoch 76/200
#  - 4s - loss: 0.1117 - mean_absolute_error: 0.1117 - val_loss: 0.1156 - val_mean_absolute_error: 0.1156
#
# Epoch 00076: val_loss did not improve from 0.10737
# Epoch 77/200
#  - 4s - loss: 0.1091 - mean_absolute_error: 0.1091 - val_loss: 0.1073 - val_mean_absolute_error: 0.1073
#
# Epoch 00077: val_loss improved from 0.10737 to 0.10727, saving model to ./keras.model
# Epoch 78/200
#  - 4s - loss: 0.1075 - mean_absolute_error: 0.1075 - val_loss: 0.1090 - val_mean_absolute_error: 0.1090
#
# Epoch 00078: val_loss did not improve from 0.10727
# Epoch 79/200
#  - 4s - loss: 0.1064 - mean_absolute_error: 0.1064 - val_loss: 0.1073 - val_mean_absolute_error: 0.1073
#
# Epoch 00079: val_loss did not improve from 0.10727
# Epoch 80/200
#  - 4s - loss: 0.1052 - mean_absolute_error: 0.1052 - val_loss: 0.1045 - val_mean_absolute_error: 0.1045
#
# Epoch 00080: val_loss improved from 0.10727 to 0.10452, saving model to ./keras.model
# Epoch 81/200
#  - 4s - loss: 0.1067 - mean_absolute_error: 0.1067 - val_loss: 0.1027 - val_mean_absolute_error: 0.1027
#
# Epoch 00081: val_loss improved from 0.10452 to 0.10268, saving model to ./keras.model
# Epoch 82/200
#  - 4s - loss: 0.1064 - mean_absolute_error: 0.1064 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
#
# Epoch 00082: val_loss did not improve from 0.10268
# Epoch 83/200
#  - 4s - loss: 0.1054 - mean_absolute_error: 0.1054 - val_loss: 0.1065 - val_mean_absolute_error: 0.1065
#
# Epoch 00083: val_loss did not improve from 0.10268
# Epoch 84/200
#  - 4s - loss: 0.1084 - mean_absolute_error: 0.1084 - val_loss: 0.1112 - val_mean_absolute_error: 0.1112
#
# Epoch 00084: val_loss did not improve from 0.10268
# Epoch 85/200
#  - 4s - loss: 0.1064 - mean_absolute_error: 0.1064 - val_loss: 0.1027 - val_mean_absolute_error: 0.1027
#
# Epoch 00085: val_loss did not improve from 0.10268
# Epoch 86/200
#  - 4s - loss: 0.1048 - mean_absolute_error: 0.1048 - val_loss: 0.1256 - val_mean_absolute_error: 0.1256
#
# Epoch 00086: val_loss did not improve from 0.10268
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 87/200
#  - 4s - loss: 0.1041 - mean_absolute_error: 0.1041 - val_loss: 0.1015 - val_mean_absolute_error: 0.1015
#
# Epoch 00087: val_loss improved from 0.10268 to 0.10153, saving model to ./keras.model
# Epoch 88/200
#  - 4s - loss: 0.0986 - mean_absolute_error: 0.0986 - val_loss: 0.1013 - val_mean_absolute_error: 0.1013
# Epoch 00088: val_loss improved from 0.10153 to 0.10131, saving model to ./keras.model
# Epoch 89/200
#  - 4s - loss: 0.0985 - mean_absolute_error: 0.0985 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
#
# Epoch 00089: val_loss improved from 0.10131 to 0.10063, saving model to ./keras.model
# Epoch 90/200
#  - 4s - loss: 0.0980 - mean_absolute_error: 0.0980 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
#
# Epoch 00090: val_loss did not improve from 0.10063
# Epoch 91/200
#  - 4s - loss: 0.0977 - mean_absolute_error: 0.0977 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
#
# Epoch 00091: val_loss did not improve from 0.10063
# Epoch 92/200
#  - 4s - loss: 0.0975 - mean_absolute_error: 0.0975 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
#
# Epoch 00092: val_loss improved from 0.10063 to 0.10050, saving model to ./keras.model
# Epoch 93/200
#  - 4s - loss: 0.0971 - mean_absolute_error: 0.0971 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
#
# Epoch 00093: val_loss did not improve from 0.10050
# Epoch 94/200
#  - 4s - loss: 0.0975 - mean_absolute_error: 0.0975 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
#
# Epoch 00094: val_loss improved from 0.10050 to 0.10016, saving model to ./keras.model
# Epoch 95/200
#  - 4s - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
#
# Epoch 00095: val_loss improved from 0.10016 to 0.09975, saving model to ./keras.model
# Epoch 96/200
#  - 4s - loss: 0.0974 - mean_absolute_error: 0.0974 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019
#
# Epoch 00096: val_loss did not improve from 0.09975
# Epoch 97/200
#  - 4s - loss: 0.0974 - mean_absolute_error: 0.0974 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
#
# Epoch 00097: val_loss did not improve from 0.09975
# Epoch 98/200
#  - 4s - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.0994 - val_mean_absolute_error: 0.0994
#
# Epoch 00098: val_loss improved from 0.09975 to 0.09940, saving model to ./keras.model
# Epoch 99/200
#  - 4s - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.1014 - val_mean_absolute_error: 0.1014
#
# Epoch 00099: val_loss did not improve from 0.09940
# Epoch 100/200
#  - 4s - loss: 0.0966 - mean_absolute_error: 0.0966 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993
#
# Epoch 00100: val_loss improved from 0.09940 to 0.09932, saving model to ./keras.model
# Epoch 101/200
#  - 4s - loss: 0.0968 - mean_absolute_error: 0.0968 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
#
# Epoch 00101: val_loss did not improve from 0.09932
# Epoch 102/200
#  - 4s - loss: 0.0969 - mean_absolute_error: 0.0969 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
#
# Epoch 00102: val_loss improved from 0.09932 to 0.09916, saving model to ./keras.model
# Epoch 103/200
#  - 4s - loss: 0.0967 - mean_absolute_error: 0.0967 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
#
# Epoch 00103: val_loss improved from 0.09916 to 0.09911, saving model to ./keras.model
# Epoch 104/200
#  - 4s - loss: 0.0967 - mean_absolute_error: 0.0967 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
#
# Epoch 00104: val_loss did not improve from 0.09911
# Epoch 105/200
#  - 4s - loss: 0.0966 - mean_absolute_error: 0.0966 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
#
# Epoch 00105: val_loss did not improve from 0.09911
# Epoch 106/200
#  - 4s - loss: 0.0962 - mean_absolute_error: 0.0962 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
#
# Epoch 00106: val_loss did not improve from 0.09911
# Epoch 107/200
#  - 4s - loss: 0.0966 - mean_absolute_error: 0.0966 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
#
# Epoch 00107: val_loss did not improve from 0.09911
#
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 108/200
#  - 4s - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
#
# Epoch 00108: val_loss did not improve from 0.09911
# Epoch 109/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00109: val_loss improved from 0.09911 to 0.09893, saving model to ./keras.model
# Epoch 110/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00110: val_loss did not improve from 0.09893
# Epoch 111/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
#
# Epoch 00111: val_loss did not improve from 0.09893
# Epoch 112/200
#  - 4s - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00112: val_loss did not improve from 0.09893
# Epoch 113/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00113: val_loss did not improve from 0.09893
# Epoch 114/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00114: val_loss did not improve from 0.09893
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 115/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00115: val_loss did not improve from 0.09893
# Epoch 116/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00116: val_loss improved from 0.09893 to 0.09890, saving model to ./keras.model
# Epoch 117/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00117: val_loss improved from 0.09890 to 0.09887, saving model to ./keras.model
# Epoch 118/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00118: val_loss did not improve from 0.09887
# Epoch 119/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00119: val_loss did not improve from 0.09887
# Epoch 120/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00120: val_loss did not improve from 0.09887
# Epoch 121/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00121: val_loss did not improve from 0.09887
# Epoch 122/200
#  - 4s - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00122: val_loss improved from 0.09887 to 0.09883, saving model to ./keras.model
# Epoch 123/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00123: val_loss improved from 0.09883 to 0.09883, saving model to ./keras.model
# Epoch 124/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00124: val_loss did not improve from 0.09883
# Epoch 125/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00125: val_loss did not improve from 0.09883
# Epoch 126/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00126: val_loss did not improve from 0.09883
# Epoch 127/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00127: val_loss did not improve from 0.09883
# Epoch 128/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00128: val_loss did not improve from 0.09883
# Epoch 129/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00129: val_loss did not improve from 0.09883
# Epoch 130/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00130: val_loss did not improve from 0.09883
# Epoch 131/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00131: val_loss did not improve from 0.09883
# Epoch 132/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00132: val_loss did not improve from 0.09883
# Epoch 133/200
#  - 5s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 00133: val_loss improved from 0.09883 to 0.09881, saving model to ./keras.model
# Epoch 134/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00134: val_loss did not improve from 0.09881
# Epoch 135/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0990 - val_mean_absolute_error: 0.0990
#
# Epoch 00135: val_loss did not improve from 0.09881
# Epoch 136/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00136: val_loss improved from 0.09881 to 0.09874, saving model to ./keras.model
# Epoch 137/200
#  - 4s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00137: val_loss did not improve from 0.09874
# Epoch 138/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
#
# Epoch 00138: val_loss did not improve from 0.09874
# Epoch 139/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00139: val_loss did not improve from 0.09874
# Epoch 140/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00140: val_loss did not improve from 0.09874
# Epoch 141/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00141: val_loss improved from 0.09874 to 0.09868, saving model to ./keras.model
# Epoch 142/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00142: val_loss did not improve from 0.09868
# Epoch 143/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00143: val_loss did not improve from 0.09868
# Epoch 144/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00144: val_loss improved from 0.09868 to 0.09863, saving model to ./keras.model
# Epoch 145/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00145: val_loss did not improve from 0.09863
# Epoch 146/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00146: val_loss did not improve from 0.09863
# Epoch 147/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00147: val_loss did not improve from 0.09863
# Epoch 148/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00148: val_loss did not improve from 0.09863
# Epoch 149/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00149: val_loss did not improve from 0.09863
# Epoch 150/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00150: val_loss did not improve from 0.09863
# Epoch 151/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00151: val_loss did not improve from 0.09863
# Epoch 152/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00152: val_loss did not improve from 0.09863
# Epoch 153/200
#  - 4s - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00153: val_loss improved from 0.09863 to 0.09858, saving model to ./keras.model
# Epoch 154/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00154: val_loss did not improve from 0.09858
# Epoch 155/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00155: val_loss did not improve from 0.09858
# Epoch 156/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00156: val_loss did not improve from 0.09858
# Epoch 157/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00157: val_loss did not improve from 0.09858
# Epoch 158/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00158: val_loss did not improve from 0.09858
# Epoch 159/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00159: val_loss did not improve from 0.09858
# Epoch 160/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00160: val_loss did not improve from 0.09858
# Epoch 161/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00161: val_loss did not improve from 0.09858
# Epoch 162/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
#
# Epoch 00162: val_loss did not improve from 0.09858
# Epoch 163/200
#  - 4s - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
#
# Epoch 00163: val_loss did not improve from 0.09858
# Epoch 00163: early stopping

# %%
epoch = history_synth.epoch
loss = history_synth.history['loss']
val = history_synth.history['val_loss']

plt.plot(epoch, loss, 'b-')
plt.plot(epoch, val, 'r.-')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split( Xdata, ydata, test_size=0.20, random_state=7)
X_train.shape
# Out:
# (283, 90, 2)

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, batch_size=16, epochs=20, 
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)
# Out:
# Train on 283 samples, validate on 71 samples
# Epoch 1/20
#  - 1s - loss: 0.2461 - mean_absolute_error: 0.2461 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850
#
# Epoch 00001: val_loss improved from inf to 0.18497, saving model to ./keras.model
# Epoch 2/20
#  - 1s - loss: 0.2341 - mean_absolute_error: 0.2341 - val_loss: 0.1779 - val_mean_absolute_error: 0.1779
#
# Epoch 00002: val_loss improved from 0.18497 to 0.17791, saving model to ./keras.model
# Epoch 3/20
#  - 1s - loss: 0.2271 - mean_absolute_error: 0.2271 - val_loss: 0.1728 - val_mean_absolute_error: 0.1728
#
# Epoch 00003: val_loss improved from 0.17791 to 0.17284, saving model to ./keras.model
# Epoch 4/20
#  - 1s - loss: 0.2221 - mean_absolute_error: 0.2221 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
#
# Epoch 00004: val_loss improved from 0.17284 to 0.16842, saving model to ./keras.model
# Epoch 5/20
#  - 1s - loss: 0.2184 - mean_absolute_error: 0.2184 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
#
# Epoch 00005: val_loss improved from 0.16842 to 0.16395, saving model to ./keras.model
# Epoch 6/20
#  - 1s - loss: 0.2156 - mean_absolute_error: 0.2156 - val_loss: 0.1610 - val_mean_absolute_error: 0.1610
#
# Epoch 00006: val_loss improved from 0.16395 to 0.16100, saving model to ./keras.model
# Epoch 7/20
#  - 1s - loss: 0.2138 - mean_absolute_error: 0.2138 - val_loss: 0.1584 - val_mean_absolute_error: 0.1584
#
# Epoch 00007: val_loss improved from 0.16100 to 0.15837, saving model to ./keras.model
# Epoch 8/20
#  - 1s - loss: 0.2120 - mean_absolute_error: 0.2120 - val_loss: 0.1573 - val_mean_absolute_error: 0.1573
#
# Epoch 00008: val_loss improved from 0.15837 to 0.15727, saving model to ./keras.model
# Epoch 9/20
#  - 1s - loss: 0.2106 - mean_absolute_error: 0.2106 - val_loss: 0.1552 - val_mean_absolute_error: 0.1552
#
# Epoch 00009: val_loss improved from 0.15727 to 0.15520, saving model to ./keras.model
# Epoch 10/20
#  - 1s - loss: 0.2093 - mean_absolute_error: 0.2093 - val_loss: 0.1521 - val_mean_absolute_error: 0.1521
#
# Epoch 00010: val_loss improved from 0.15520 to 0.15210, saving model to ./keras.model
# Epoch 11/20
#  - 1s - loss: 0.2079 - mean_absolute_error: 0.2079 - val_loss: 0.1506 - val_mean_absolute_error: 0.1506
#
# Epoch 00011: val_loss improved from 0.15210 to 0.15065, saving model to ./keras.model
# Epoch 12/20
#  - 1s - loss: 0.2068 - mean_absolute_error: 0.2068 - val_loss: 0.1486 - val_mean_absolute_error: 0.1486
#
# Epoch 00012: val_loss improved from 0.15065 to 0.14863, saving model to ./keras.model
# Epoch 13/20
#  - 1s - loss: 0.2058 - mean_absolute_error: 0.2058 - val_loss: 0.1476 - val_mean_absolute_error: 0.1476
#
# Epoch 00013: val_loss improved from 0.14863 to 0.14761, saving model to ./keras.model
# Epoch 14/20
#  - 1s - loss: 0.2050 - mean_absolute_error: 0.2050 - val_loss: 0.1462 - val_mean_absolute_error: 0.1462
#
# Epoch 00014: val_loss improved from 0.14761 to 0.14615, saving model to ./keras.model
# Epoch 15/20
#  - 1s - loss: 0.2042 - mean_absolute_error: 0.2042 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452
#
# Epoch 00015: val_loss improved from 0.14615 to 0.14524, saving model to ./keras.model
# Epoch 16/20
#  - 1s - loss: 0.2035 - mean_absolute_error: 0.2035 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449
#
# Epoch 00016: val_loss improved from 0.14524 to 0.14492, saving model to ./keras.model
# Epoch 17/20
#  - 1s - loss: 0.2028 - mean_absolute_error: 0.2028 - val_loss: 0.1442 - val_mean_absolute_error: 0.1442
#
# Epoch 00017: val_loss improved from 0.14492 to 0.14421, saving model to ./keras.model
# Epoch 18/20
#  - 1s - loss: 0.2023 - mean_absolute_error: 0.2023 - val_loss: 0.1435 - val_mean_absolute_error: 0.1435
#
# Epoch 00018: val_loss improved from 0.14421 to 0.14347, saving model to ./keras.model
# Epoch 19/20
#  - 1s - loss: 0.2016 - mean_absolute_error: 0.2016 - val_loss: 0.1425 - val_mean_absolute_error: 0.1425
#
# Epoch 00019: val_loss improved from 0.14347 to 0.14247, saving model to ./keras.model
# Epoch 20/20
#  - 1s - loss: 0.2009 - mean_absolute_error: 0.2009 - val_loss: 0.1430 - val_mean_absolute_error: 0.1430
#
# Epoch 00020: val_loss did not improve from 0.14247

# %%
epoch = history.epoch
loss = history.history['loss']
val = history.history['val_loss']

plt.figure(figsize=(8,6))
plt.plot(epoch, loss, 'bx-', label='Training')
plt.plot(epoch, val, 'r.-', label='Validation')
plt.ylim(0.1, 0.4)
plt.xlim(0, 21)
plt.xticks(np.arange(0,21, 2))
plt.title('RNN Model Pre-Trained with Synthetic Data', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('Mean Absolute Error', fontsize=14)
plt.legend()
plt.show()

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)

history2 = model.fit(X_train, y_train, batch_size=16, epochs=20, 
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=2)
# Out:
# Train on 283 samples, validate on 71 samples
# Epoch 1/20
#  - 2s - loss: 0.3725 - mean_absolute_error: 0.3725 - val_loss: 0.2496 - val_mean_absolute_error: 0.2496
#
# Epoch 00001: val_loss improved from inf to 0.24955, saving model to ./keras.model
# Epoch 2/20
#  - 1s - loss: 0.2922 - mean_absolute_error: 0.2922 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211
#
# Epoch 00002: val_loss improved from 0.24955 to 0.22106, saving model to ./keras.model
# Epoch 3/20
#  - 1s - loss: 0.2860 - mean_absolute_error: 0.2860 - val_loss: 0.2159 - val_mean_absolute_error: 0.2159
#
# Epoch 00003: val_loss improved from 0.22106 to 0.21587, saving model to ./keras.model
# Epoch 4/20
#  - 1s - loss: 0.2778 - mean_absolute_error: 0.2778 - val_loss: 0.1968 - val_mean_absolute_error: 0.1968
#
# Epoch 00004: val_loss improved from 0.21587 to 0.19680, saving model to ./keras.model
# Epoch 5/20
#  - 1s - loss: 0.2691 - mean_absolute_error: 0.2691 - val_loss: 0.1974 - val_mean_absolute_error: 0.1974
#
# Epoch 00005: val_loss did not improve from 0.19680
# Epoch 6/20
#  - 1s - loss: 0.2684 - mean_absolute_error: 0.2684 - val_loss: 0.1969 - val_mean_absolute_error: 0.1969
#
# Epoch 00006: val_loss did not improve from 0.19680
# Epoch 7/20
#  - 1s - loss: 0.2669 - mean_absolute_error: 0.2669 - val_loss: 0.1970 - val_mean_absolute_error: 0.1970
#
# Epoch 00007: val_loss did not improve from 0.19680
# Epoch 8/20
#  - 1s - loss: 0.2653 - mean_absolute_error: 0.2653 - val_loss: 0.1970 - val_mean_absolute_error: 0.1970
#
# Epoch 00008: val_loss did not improve from 0.19680
# Epoch 9/20
#  - 1s - loss: 0.2660 - mean_absolute_error: 0.2660 - val_loss: 0.1976 - val_mean_absolute_error: 0.1976
#
# Epoch 00009: val_loss did not improve from 0.19680
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/20
#  - 1s - loss: 0.2632 - mean_absolute_error: 0.2632 - val_loss: 0.1972 - val_mean_absolute_error: 0.1972
#
# Epoch 00010: val_loss did not improve from 0.19680
# Epoch 11/20
#  - 1s - loss: 0.2621 - mean_absolute_error: 0.2621 - val_loss: 0.1959 - val_mean_absolute_error: 0.1959
#
# Epoch 00011: val_loss improved from 0.19680 to 0.19592, saving model to ./keras.model
# Epoch 12/20
#  - 1s - loss: 0.2613 - mean_absolute_error: 0.2613 - val_loss: 0.1959 - val_mean_absolute_error: 0.1959
#
# Epoch 00012: val_loss did not improve from 0.19592
# Epoch 13/20
#  - 1s - loss: 0.2611 - mean_absolute_error: 0.2611 - val_loss: 0.1961 - val_mean_absolute_error: 0.1961
#
# Epoch 00013: val_loss did not improve from 0.19592
# Epoch 14/20
#  - 1s - loss: 0.2609 - mean_absolute_error: 0.2609 - val_loss: 0.1957 - val_mean_absolute_error: 0.1957
#
# Epoch 00014: val_loss improved from 0.19592 to 0.19567, saving model to ./keras.model
# Epoch 15/20
#  - 1s - loss: 0.2608 - mean_absolute_error: 0.2608 - val_loss: 0.1956 - val_mean_absolute_error: 0.1956
#
# Epoch 00015: val_loss improved from 0.19567 to 0.19556, saving model to ./keras.model
# Epoch 16/20
#  - 1s - loss: 0.2603 - mean_absolute_error: 0.2603 - val_loss: 0.1951 - val_mean_absolute_error: 0.1951
#
# Epoch 00016: val_loss improved from 0.19556 to 0.19510, saving model to ./keras.model
# Epoch 17/20
#  - 1s - loss: 0.2603 - mean_absolute_error: 0.2603 - val_loss: 0.1951 - val_mean_absolute_error: 0.1951
#
# Epoch 00017: val_loss did not improve from 0.19510
# Epoch 18/20
#  - 1s - loss: 0.2600 - mean_absolute_error: 0.2600 - val_loss: 0.1947 - val_mean_absolute_error: 0.1947
#
# Epoch 00018: val_loss improved from 0.19510 to 0.19466, saving model to ./keras.model
# Epoch 19/20
#  - 1s - loss: 0.2597 - mean_absolute_error: 0.2597 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944
#
# Epoch 00019: val_loss improved from 0.19466 to 0.19439, saving model to ./keras.model
# Epoch 20/20
#  - 1s - loss: 0.2594 - mean_absolute_error: 0.2594 - val_loss: 0.1941 - val_mean_absolute_error: 0.1941
#
# Epoch 00020: val_loss improved from 0.19439 to 0.19408, saving model to ./keras.model

# %%
epoch = history2.epoch
loss = history2.history['loss']
val = history2.history['val_loss']

plt.figure(figsize=(8,6))
plt.plot(epoch, loss, 'bx-', label='Training')
plt.plot(epoch, val, 'r.-', label='Validation')
plt.ylim(0.1, 0.4)
plt.xlim(0, 21)
plt.xticks(np.arange(0,21, 2))
plt.title('RNN Model Trained with Real Data only', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('Mean Absolute Error', fontsize=14)
plt.legend()
plt.show()
